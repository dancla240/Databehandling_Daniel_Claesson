# %% [markdown]
# # Bool mask and bool indexing
# [Link to recording](https://ithogskolan.sharepoint.com/:v:/s/AI23/ESFlarMdHPJEo-PfSJ9uDRsBx4BVEj_XJydhY1ojRjEELA?e=Bi86C2)

# %%
import numpy as np
import pandas as pd

# %%
floats = pd.DataFrame(np.random.randn(7,4), columns=["A","B","C","D"])
floats
# Out:
#           A         B         C         D
# 0 -1.482518 -1.194780 -0.876744  0.086074
# 1 -0.988047 -0.655083 -1.754372  0.612897
# 2  1.495308 -0.584976  0.240772 -0.608840
# 3 -1.215965 -0.864099 -0.815398  0.892250
# 4 -0.519582  0.015412  1.382414 -0.639329
# 5 -0.778066  0.482072 -0.608363  1.166825
# 6 -1.346164  0.474615 -0.523149 -0.300494

# %%
floats["B"]
# Out:
# 0   -1.194780
# 1   -0.655083
# 2   -0.584976
# 3   -0.864099
# 4    0.015412
# 5    0.482072
# 6    0.474615
# Name: B, dtype: float64

# %% [markdown]
# Creating bool mask for column "B"

# %%
floats["B"] >= 0
# Out:
# 0    False
# 1    False
# 2    False
# 3    False
# 4     True
# 5     True
# 6     True
# Name: B, dtype: bool

# %%
floats[floats["B"] >= 0]
# Out:
#           A         B         C         D
# 4 -0.519582  0.015412  1.382414 -0.639329
# 5 -0.778066  0.482072 -0.608363  1.166825
# 6 -1.346164  0.474615 -0.523149 -0.300494

# %% [markdown]
# Creating bool mask for row 0

# %%
floats.loc[0,:] >= 0
# Out:
# A    False
# B    False
# C    False
# D     True
# Name: 0, dtype: bool

# %%
floats.loc[:,floats.loc[0,:] >= 0]
# Out:
#           D
# 0  0.086074
# 1  0.612897
# 2 -0.608840
# 3  0.892250
# 4 -0.639329
# 5  1.166825
# 6 -0.300494

# %% [markdown]
# # Querying data
# - filtering rows based on values of certain attributes can be done either with bool index or pandas query method
# - Bool mask och Query är två sätt att filtrera datan. Query filtrerar på innehållet i datan.
# - Födel med Bool Mask kan man även sätta värden på det man letat upp

# %%
autos = pd.read_json("../Data/autos_json.json")
autos
# Out:
#     aspiration   body-style  bore  city-mpg  compression-ratio  curb-weight  \
# 0          std  convertible  3.47        21                9.0         2548
# 1          std  convertible  3.47        21                9.0         2548
# 2          std    hatchback  2.68        19                9.0         2823
# 3          std        sedan  3.19        24               10.0         2337
# 4          std        sedan  3.19        18                8.0         2824
# ..         ...          ...   ...       ...                ...          ...
# 200        std        sedan  3.78        23                9.5         2952
# 201      turbo        sedan  3.78        19                8.7         3049
# 202        std        sedan  3.58        18                8.8         3012
# 203      turbo        sedan  3.01        26               23.0         3217
# 204      turbo        sedan  3.78        19                9.5         3062
#
# ...

# %%
autos[autos["make"] == "volvo"]
# Out:
#     aspiration body-style  bore  city-mpg  compression-ratio  curb-weight  \
# 194        std      sedan  3.78        23                9.5         2912
# 195        std      wagon  3.78        23                9.5         3034
# 196        std      sedan  3.78        24                9.5         2935
# 197        std      wagon  3.78        24                9.5         3042
# 198      turbo      sedan  3.62        17                7.5         3045
# 199      turbo      wagon  3.62        17                7.5         3157
# 200        std      sedan  3.78        23                9.5         2952
# 201      turbo      sedan  3.78        19                8.7         3049
# 202        std      sedan  3.58        18                8.8         3012
# 203      turbo      sedan  3.01        26               23.0         3217
# 204      turbo      sedan  3.78        19                9.5         3062
#
#     drive-wheels engine-location  engine-size engine-type  ...   make  \
# ...

# %%
import seaborn as sns

sns.relplot(x="engine-size", y="price", data=autos)
sns.relplot(x="engine-size", y="price", data=autos)

# %% [markdown]
# ### Sorting DataFrame
# - DataFrames can be sorted using the .sort_values() method
#
# Parameters:
# - **by** column, or list of columns
# - **ascending** option. Default=True

# %%
autos.sort_values(by="engine-size", ascending=True)
# Out:
#    aspiration body-style  bore  city-mpg  compression-ratio  curb-weight  \
# 18        std  hatchback  2.91        47                9.5         1488
# 57        std  hatchback   NaN        17                9.4         2385
# 55        std  hatchback   NaN        17                9.4         2380
# 56        std  hatchback   NaN        17                9.4         2380
# 32        std  hatchback  2.91        38               10.1         1837
# ..        ...        ...   ...       ...                ...          ...
# 48        std      sedan  3.63        15                8.1         4066
# 47        std      sedan  3.63        15                8.1         4066
# 74        std    hardtop  3.80        14                8.0         3715
# 73        std      sedan  3.80        14                8.0         3900
# 49        std      sedan  3.54        13               11.5         3950
#
#    drive-wheels engine-location  engine-size engine-type  ...           make  \
# ...

# %%
autos.sort_values(by=["make","engine-size"], ascending=[False, True])
# Out:
#     aspiration   body-style  bore  city-mpg  compression-ratio  curb-weight  \
# 198      turbo        sedan  3.62        17                7.5         3045
# 199      turbo        wagon  3.62        17                7.5         3157
# 194        std        sedan  3.78        23                9.5         2912
# 195        std        wagon  3.78        23                9.5         3034
# 196        std        sedan  3.78        24                9.5         2935
# ..         ...          ...   ...       ...                ...          ...
# 6          std        sedan  3.19        19                8.5         2844
# 7          std        wagon  3.19        19                8.5         2954
# 0          std  convertible  3.47        21                9.0         2548
# 1          std  convertible  3.47        21                9.0         2548
# 2          std    hatchback  2.68        19                9.0         2823
#
# ...
