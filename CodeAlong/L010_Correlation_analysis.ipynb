# %% [markdown]
# # Correlation analyis
# [Lecture](https://ithogskolan.sharepoint.com/:v:/s/AI23/EVM3kTeo1gFDiQuMElQ-1YcBP1UTThO601abub20Xf9LxQ?e=vezjHz)
# - correlation analysis is a statistical technique used to esamine the strength and direction of the relationship between two or more variables. It involves analysing the degree to which changes in one variable is associated with changes in another variable.
#
# ### Pandas .corr() method
# - Claculates the the correlation coefficients between all pairs of features in dataframe, and returns a new dataframe where the number of rows and columns both

# %%
import pandas as pd
import seaborn as sns
import warnings

warnings.filterwarnings("ignore", "is_categorical_dtype")
warnings.filterwarnings("ignore", "use_inf_as_na")
warnings.filterwarnings("ignore", "The figure layout has changed to tight")
warnings.filterwarnings("ignore", "The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.")
warnings.filterwarnings("ignore", "is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead. if is_sparse(pd_dtype):")

# %% [markdown]
# Läser in data på .json format, som vi sparade i L09. Där all categorical data ersatt med numerisk data, så att säga.

# %%
titanic = pd.read_json("../Data/titanic_encoded.json")
titanic.head()
# Out:
#    survived  pclass  sex   age  sibsp  parch     fare  embarked  class  who  \
# 0         0       3    1  22.0      1      0   7.2500       0.0      2    1
# 1         1       1    0  38.0      1      0  71.2833       1.0      0    2
# 2         1       3    0  26.0      0      0   7.9250       0.0      2    2
# 3         1       1    0  35.0      1      0  53.1000       0.0      0    2
# 4         0       3    1  35.0      0      0   8.0500       0.0      2    1
#
#    adult_male  deck  embark_town  alive  alone
# 0           1     7            2      0      0
# 1           0     2            0      1      0
# 2           0     7            2      1      1
# 3           0     2            2      1      0
# 4           1     7            2      0      1

# %%
# Nu kör vi corr() metoden på datan:
correlation_matrix = titanic.corr()
correlation_matrix
# Out:
#              survived    pclass       sex       age     sibsp     parch  \
# survived     1.000000 -0.338481 -0.543351 -0.077221 -0.035322  0.081629
# pclass      -0.338481  1.000000  0.131900 -0.369226  0.083081  0.018443
# sex         -0.543351  0.131900  1.000000  0.093254 -0.114631 -0.245489
# age         -0.077221 -0.369226  0.093254  1.000000 -0.308247 -0.189119
# sibsp       -0.035322  0.083081 -0.114631 -0.308247  1.000000  0.414838
# parch        0.081629  0.018443 -0.245489 -0.189119  0.414838  1.000000
# fare         0.257307 -0.549500 -0.182333  0.096067  0.159651  0.216225
# embarked     0.108669  0.043835 -0.118593  0.012186 -0.060606 -0.079320
# class       -0.338481  1.000000  0.131900 -0.369226  0.083081  0.018443
# who          0.325753 -0.196793 -0.639773  0.378685 -0.136003 -0.055682
# adult_male  -0.557080  0.094035  0.908578  0.280328 -0.253586 -0.349943
# deck        -0.294804  0.743251  0.118282 -0.267987  0.041333 -0.031308
# ...

# %% [markdown]
# # Här finns mer för mig att kolla på föreläsningen om jag orkar....
