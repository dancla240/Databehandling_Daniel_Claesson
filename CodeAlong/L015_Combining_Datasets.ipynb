# %% [markdown]
# ## Combining Datasets
# - Pandas provides variuos facilites for easily combining together Series and Dataframes.
# - **Concat:** combining dataframes accross rows or columns.
# - **Join:** combining data on a key column or index.
# - **Merge:** combining data on common columns or indexes.
#
# - [Pandas doc: Merge, join, concatenate and compare](https://pandas.pydata.org/docs/user_guide/merging.html)
# - [Lecture 1: Concatenate](https://ithogskolan.sharepoint.com/:v:/s/AI23/EbTtg5bm5H9Npz52kNXsZREBlX7ZvGoGrA3j0qxpErJO2Q?e=WPwpyt)
# - [Lecture 2 del 1: Join](https://ithogskolan.sharepoint.com/:v:/s/AI23/EW9LEQWccOZBtwTU4SIP2PYBknNU7w7j-RZagqc_JYQO5A?e=kYMoRy)
# - [Lecture 2 del 2: Join forts](https://ithogskolan.sharepoint.com/:v:/s/AI23/EXjIVmeBz61ClFAJXqrBfGEBjnti4xWXh3Hs15REPYifTg?e=rGXIXt)
# - [Lecture 3: Merge](https://ithogskolan.sharepoint.com/:v:/s/AI23/EQuJSVzyqZNCprBWVDJBRUsB1YerzByfniGBxTYyBh08iQ?e=aFy0nF)
# - [Lecture 4: Mini challenge och mer om Multi-indexing](https://ithogskolan.sharepoint.com/:v:/s/AI23/EYfXBuhcyIlMqARV1cbL7lsBALXK6MxRjNgL2TkqPg7ULg?e=x0EeMg)

# %%
from helpers import sample_df, hdisplay, nowrap_display
import pandas as pd

# %% [markdown]
# ### Concat
# - Pandas .concat() method concatenates dataframes row- or columnwice, with optional set logic (union or intersection) of the indexes on the other axis.
# - Concat simply stacks multiple dataframes together either vertically or horizontally after **alligning row / column**.
# - Parameters:
#     - join='inner' or 'outer'(default)
#     - prefix
#     - axis='index' or 'column'

# %%
# Sample Data
left = sample_df("A0","D3", prefix="L")
right = sample_df("A0","D3", prefix="R")
hdisplay([left, right])
# Out:
# <style type="text/css">
# #T_41a85 th {
#   text-align: left;
#   vertical-align: top;
# }
# </style>
# <table id="T_41a85" style='display:inline; margin-right: 50px;'>
#   <caption>DataFrame 0</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_41a85_level0_col0" class="col_heading level0 col0" >A</th>
#       <th id="T_41a85_level0_col1" class="col_heading level0 col1" >B</th>
#       <th id="T_41a85_level0_col2" class="col_heading level0 col2" >C</th>
#       <th id="T_41a85_level0_col3" class="col_heading level0 col3" >D</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_41a85_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_41a85_row0_col0" class="data row0 col0" >LA0</td>
#       <td id="T_41a85_row0_col1" class="data row0 col1" >LB0</td>
#       <td id="T_41a85_row0_col2" class="data row0 col2" >LC0</td>
#       <td id="T_41a85_row0_col3" class="data row0 col3" >LD0</td>
#     </tr>
#     <tr>
#       <th id="T_41a85_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_41a85_row1_col0" class="data row1 col0" >LA1</td>
#       <td id="T_41a85_row1_col1" class="data row1 col1" >LB1</td>
#       <td id="T_41a85_row1_col2" class="data row1 col2" >LC1</td>
#       <td id="T_41a85_row1_col3" class="data row1 col3" >LD1</td>
#     </tr>
#     <tr>
#       <th id="T_41a85_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_41a85_row2_col0" class="data row2 col0" >LA2</td>
#       <td id="T_41a85_row2_col1" class="data row2 col1" >LB2</td>
#       <td id="T_41a85_row2_col2" class="data row2 col2" >LC2</td>
#       <td id="T_41a85_row2_col3" class="data row2 col3" >LD2</td>
#     </tr>
#     <tr>
#       <th id="T_41a85_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_41a85_row3_col0" class="data row3 col0" >LA3</td>
#       <td id="T_41a85_row3_col1" class="data row3 col1" >LB3</td>
#       <td id="T_41a85_row3_col2" class="data row3 col2" >LC3</td>
#       <td id="T_41a85_row3_col3" class="data row3 col3" >LD3</td>
#     </tr>
#   </tbody>
# </table>
# <style type="text/css">
# #T_78625 th {
#   text-align: left;
#   vertical-align: top;
# }
# </style>
# <table id="T_78625" style='display:inline; margin-right: 50px;'>
#   <caption>DataFrame 1</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_78625_level0_col0" class="col_heading level0 col0" >A</th>
#       <th id="T_78625_level0_col1" class="col_heading level0 col1" >B</th>
#       <th id="T_78625_level0_col2" class="col_heading level0 col2" >C</th>
#       <th id="T_78625_level0_col3" class="col_heading level0 col3" >D</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_78625_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_78625_row0_col0" class="data row0 col0" >RA0</td>
#       <td id="T_78625_row0_col1" class="data row0 col1" >RB0</td>
#       <td id="T_78625_row0_col2" class="data row0 col2" >RC0</td>
#       <td id="T_78625_row0_col3" class="data row0 col3" >RD0</td>
#     </tr>
#     <tr>
#       <th id="T_78625_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_78625_row1_col0" class="data row1 col0" >RA1</td>
#       <td id="T_78625_row1_col1" class="data row1 col1" >RB1</td>
#       <td id="T_78625_row1_col2" class="data row1 col2" >RC1</td>
#       <td id="T_78625_row1_col3" class="data row1 col3" >RD1</td>
#     </tr>
#     <tr>
#       <th id="T_78625_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_78625_row2_col0" class="data row2 col0" >RA2</td>
#       <td id="T_78625_row2_col1" class="data row2 col1" >RB2</td>
#       <td id="T_78625_row2_col2" class="data row2 col2" >RC2</td>
#       <td id="T_78625_row2_col3" class="data row2 col3" >RD2</td>
#     </tr>
#     <tr>
#       <th id="T_78625_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_78625_row3_col0" class="data row3 col0" >RA3</td>
#       <td id="T_78625_row3_col1" class="data row3 col1" >RB3</td>
#       <td id="T_78625_row3_col2" class="data row3 col2" >RC3</td>
#       <td id="T_78625_row3_col3" class="data row3 col3" >RD3</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# Concat tar en lista av dataframes.
# - Default axis=index

# %%
pd.concat([left, right])
# Out:
#      A    B    C    D
# 0  LA0  LB0  LC0  LD0
# 1  LA1  LB1  LC1  LD1
# 2  LA2  LB2  LC2  LD2
# 3  LA3  LB3  LC3  LD3
# 0  RA0  RB0  RC0  RD0
# 1  RA1  RB1  RC1  RD1
# 2  RA2  RB2  RC2  RD2
# 3  RA3  RB3  RC3  RD3

# %%
pd.concat([left, right], axis='columns')
# Out:
#      A    B    C    D    A    B    C    D
# 0  LA0  LB0  LC0  LD0  RA0  RB0  RC0  RD0
# 1  LA1  LB1  LC1  LD1  RA1  RB1  RC1  RD1
# 2  LA2  LB2  LC2  LD2  RA2  RB2  RC2  RD2
# 3  LA3  LB3  LC3  LD3  RA3  RB3  RC3  RD3

# %% [markdown]
# Ofta vill man ha indexen unika, det finns en metod för det.
# - tex .reset_index(drop=True), den skapar ett nytt index från noll och uppåt
# - df.set_index('col'), tar en kolumn och sätter det till index
# - ignore_index=True, parameter man skickar med concat om man vill "reseta" indexen, dvs från noll och uppåt. False är default.

# %%
#27
hdisplay([
    pd.concat([left, right], axis='index'),
    pd.concat([left, right], axis='columns', join='outer'), #liknande set union, default
    pd.concat([left, right], axis='columns', join='inner')], #liknadne set intersection
    ["axis='index'","axis='columns', join='outer'","axis='columns', join='inner'"],
    20
    )
# Out:
# <style type="text/css">
# #T_2aa59 th {
#   text-align: left;
#   vertical-align: top;
# }
# </style>
# <table id="T_2aa59" style='display:inline; margin-right: 20px;'>
#   <caption>axis='index'</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_2aa59_level0_col0" class="col_heading level0 col0" >A</th>
#       <th id="T_2aa59_level0_col1" class="col_heading level0 col1" >B</th>
#       <th id="T_2aa59_level0_col2" class="col_heading level0 col2" >C</th>
#       <th id="T_2aa59_level0_col3" class="col_heading level0 col3" >D</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_2aa59_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_2aa59_row0_col0" class="data row0 col0" >LA0</td>
#       <td id="T_2aa59_row0_col1" class="data row0 col1" >LB0</td>
#       <td id="T_2aa59_row0_col2" class="data row0 col2" >LC0</td>
#       <td id="T_2aa59_row0_col3" class="data row0 col3" >LD0</td>
#     </tr>
#     <tr>
#       <th id="T_2aa59_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_2aa59_row1_col0" class="data row1 col0" >LA1</td>
#       <td id="T_2aa59_row1_col1" class="data row1 col1" >LB1</td>
#       <td id="T_2aa59_row1_col2" class="data row1 col2" >LC1</td>
#       <td id="T_2aa59_row1_col3" class="data row1 col3" >LD1</td>
#     </tr>
#     <tr>
#       <th id="T_2aa59_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_2aa59_row2_col0" class="data row2 col0" >LA2</td>
#       <td id="T_2aa59_row2_col1" class="data row2 col1" >LB2</td>
#       <td id="T_2aa59_row2_col2" class="data row2 col2" >LC2</td>
#       <td id="T_2aa59_row2_col3" class="data row2 col3" >LD2</td>
#     </tr>
#     <tr>
#       <th id="T_2aa59_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_2aa59_row3_col0" class="data row3 col0" >LA3</td>
#       <td id="T_2aa59_row3_col1" class="data row3 col1" >LB3</td>
#       <td id="T_2aa59_row3_col2" class="data row3 col2" >LC3</td>
#       <td id="T_2aa59_row3_col3" class="data row3 col3" >LD3</td>
#     </tr>
#     <tr>
#       <th id="T_2aa59_level0_row4" class="row_heading level0 row4" >0</th>
#       <td id="T_2aa59_row4_col0" class="data row4 col0" >RA0</td>
#       <td id="T_2aa59_row4_col1" class="data row4 col1" >RB0</td>
#       <td id="T_2aa59_row4_col2" class="data row4 col2" >RC0</td>
#       <td id="T_2aa59_row4_col3" class="data row4 col3" >RD0</td>
#     </tr>
#     <tr>
#       <th id="T_2aa59_level0_row5" class="row_heading level0 row5" >1</th>
#       <td id="T_2aa59_row5_col0" class="data row5 col0" >RA1</td>
#       <td id="T_2aa59_row5_col1" class="data row5 col1" >RB1</td>
#       <td id="T_2aa59_row5_col2" class="data row5 col2" >RC1</td>
#       <td id="T_2aa59_row5_col3" class="data row5 col3" >RD1</td>
#     </tr>
#     <tr>
#       <th id="T_2aa59_level0_row6" class="row_heading level0 row6" >2</th>
#       <td id="T_2aa59_row6_col0" class="data row6 col0" >RA2</td>
#       <td id="T_2aa59_row6_col1" class="data row6 col1" >RB2</td>
#       <td id="T_2aa59_row6_col2" class="data row6 col2" >RC2</td>
#       <td id="T_2aa59_row6_col3" class="data row6 col3" >RD2</td>
#     </tr>
#     <tr>
#       <th id="T_2aa59_level0_row7" class="row_heading level0 row7" >3</th>
#       <td id="T_2aa59_row7_col0" class="data row7 col0" >RA3</td>
#       <td id="T_2aa59_row7_col1" class="data row7 col1" >RB3</td>
#       <td id="T_2aa59_row7_col2" class="data row7 col2" >RC3</td>
#       <td id="T_2aa59_row7_col3" class="data row7 col3" >RD3</td>
#     </tr>
#   </tbody>
# </table>
# <style type="text/css">
# #T_0b740 th {
#   text-align: left;
#   vertical-align: top;
# }
# </style>
# <table id="T_0b740" style='display:inline; margin-right: 20px;'>
#   <caption>axis='columns', join='outer'</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_0b740_level0_col0" class="col_heading level0 col0" >A</th>
#       <th id="T_0b740_level0_col1" class="col_heading level0 col1" >B</th>
#       <th id="T_0b740_level0_col2" class="col_heading level0 col2" >C</th>
#       <th id="T_0b740_level0_col3" class="col_heading level0 col3" >D</th>
#       <th id="T_0b740_level0_col4" class="col_heading level0 col4" >A</th>
#       <th id="T_0b740_level0_col5" class="col_heading level0 col5" >B</th>
#       <th id="T_0b740_level0_col6" class="col_heading level0 col6" >C</th>
#       <th id="T_0b740_level0_col7" class="col_heading level0 col7" >D</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_0b740_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_0b740_row0_col0" class="data row0 col0" >LA0</td>
#       <td id="T_0b740_row0_col1" class="data row0 col1" >LB0</td>
#       <td id="T_0b740_row0_col2" class="data row0 col2" >LC0</td>
#       <td id="T_0b740_row0_col3" class="data row0 col3" >LD0</td>
#       <td id="T_0b740_row0_col4" class="data row0 col4" >RA0</td>
#       <td id="T_0b740_row0_col5" class="data row0 col5" >RB0</td>
#       <td id="T_0b740_row0_col6" class="data row0 col6" >RC0</td>
#       <td id="T_0b740_row0_col7" class="data row0 col7" >RD0</td>
#     </tr>
#     <tr>
#       <th id="T_0b740_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_0b740_row1_col0" class="data row1 col0" >LA1</td>
#       <td id="T_0b740_row1_col1" class="data row1 col1" >LB1</td>
#       <td id="T_0b740_row1_col2" class="data row1 col2" >LC1</td>
#       <td id="T_0b740_row1_col3" class="data row1 col3" >LD1</td>
#       <td id="T_0b740_row1_col4" class="data row1 col4" >RA1</td>
#       <td id="T_0b740_row1_col5" class="data row1 col5" >RB1</td>
#       <td id="T_0b740_row1_col6" class="data row1 col6" >RC1</td>
#       <td id="T_0b740_row1_col7" class="data row1 col7" >RD1</td>
#     </tr>
#     <tr>
#       <th id="T_0b740_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_0b740_row2_col0" class="data row2 col0" >LA2</td>
#       <td id="T_0b740_row2_col1" class="data row2 col1" >LB2</td>
#       <td id="T_0b740_row2_col2" class="data row2 col2" >LC2</td>
#       <td id="T_0b740_row2_col3" class="data row2 col3" >LD2</td>
#       <td id="T_0b740_row2_col4" class="data row2 col4" >RA2</td>
#       <td id="T_0b740_row2_col5" class="data row2 col5" >RB2</td>
#       <td id="T_0b740_row2_col6" class="data row2 col6" >RC2</td>
#       <td id="T_0b740_row2_col7" class="data row2 col7" >RD2</td>
#     </tr>
#     <tr>
#       <th id="T_0b740_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_0b740_row3_col0" class="data row3 col0" >LA3</td>
#       <td id="T_0b740_row3_col1" class="data row3 col1" >LB3</td>
#       <td id="T_0b740_row3_col2" class="data row3 col2" >LC3</td>
#       <td id="T_0b740_row3_col3" class="data row3 col3" >LD3</td>
#       <td id="T_0b740_row3_col4" class="data row3 col4" >RA3</td>
#       <td id="T_0b740_row3_col5" class="data row3 col5" >RB3</td>
#       <td id="T_0b740_row3_col6" class="data row3 col6" >RC3</td>
#       <td id="T_0b740_row3_col7" class="data row3 col7" >RD3</td>
#     </tr>
#   </tbody>
# </table>
# <style type="text/css">
# #T_8fb61 th {
#   text-align: left;
#   vertical-align: top;
# }
# </style>
# <table id="T_8fb61" style='display:inline; margin-right: 20px;'>
#   <caption>axis='columns', join='inner'</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_8fb61_level0_col0" class="col_heading level0 col0" >A</th>
#       <th id="T_8fb61_level0_col1" class="col_heading level0 col1" >B</th>
#       <th id="T_8fb61_level0_col2" class="col_heading level0 col2" >C</th>
#       <th id="T_8fb61_level0_col3" class="col_heading level0 col3" >D</th>
#       <th id="T_8fb61_level0_col4" class="col_heading level0 col4" >A</th>
#       <th id="T_8fb61_level0_col5" class="col_heading level0 col5" >B</th>
#       <th id="T_8fb61_level0_col6" class="col_heading level0 col6" >C</th>
#       <th id="T_8fb61_level0_col7" class="col_heading level0 col7" >D</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_8fb61_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_8fb61_row0_col0" class="data row0 col0" >LA0</td>
#       <td id="T_8fb61_row0_col1" class="data row0 col1" >LB0</td>

# %%
# New sample data, delvis matchande kolumner och index:

left = sample_df("A0","D3", prefix="L")
right = sample_df("C2","F5", prefix="R")
hdisplay([left, right], ['Left','Right'])
# Out:
# <style type="text/css">
# #T_3f029 th {
#   text-align: left;
#   vertical-align: top;
# }
# </style>
# <table id="T_3f029" style='display:inline; margin-right: 50px;'>
#   <caption>Left</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_3f029_level0_col0" class="col_heading level0 col0" >A</th>
#       <th id="T_3f029_level0_col1" class="col_heading level0 col1" >B</th>
#       <th id="T_3f029_level0_col2" class="col_heading level0 col2" >C</th>
#       <th id="T_3f029_level0_col3" class="col_heading level0 col3" >D</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_3f029_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_3f029_row0_col0" class="data row0 col0" >LA0</td>
#       <td id="T_3f029_row0_col1" class="data row0 col1" >LB0</td>
#       <td id="T_3f029_row0_col2" class="data row0 col2" >LC0</td>
#       <td id="T_3f029_row0_col3" class="data row0 col3" >LD0</td>
#     </tr>
#     <tr>
#       <th id="T_3f029_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_3f029_row1_col0" class="data row1 col0" >LA1</td>
#       <td id="T_3f029_row1_col1" class="data row1 col1" >LB1</td>
#       <td id="T_3f029_row1_col2" class="data row1 col2" >LC1</td>
#       <td id="T_3f029_row1_col3" class="data row1 col3" >LD1</td>
#     </tr>
#     <tr>
#       <th id="T_3f029_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_3f029_row2_col0" class="data row2 col0" >LA2</td>
#       <td id="T_3f029_row2_col1" class="data row2 col1" >LB2</td>
#       <td id="T_3f029_row2_col2" class="data row2 col2" >LC2</td>
#       <td id="T_3f029_row2_col3" class="data row2 col3" >LD2</td>
#     </tr>
#     <tr>
#       <th id="T_3f029_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_3f029_row3_col0" class="data row3 col0" >LA3</td>
#       <td id="T_3f029_row3_col1" class="data row3 col1" >LB3</td>
#       <td id="T_3f029_row3_col2" class="data row3 col2" >LC3</td>
#       <td id="T_3f029_row3_col3" class="data row3 col3" >LD3</td>
#     </tr>
#   </tbody>
# </table>
# <style type="text/css">
# #T_a3efe th {
#   text-align: left;
#   vertical-align: top;
# }
# </style>
# <table id="T_a3efe" style='display:inline; margin-right: 50px;'>
#   <caption>Right</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_a3efe_level0_col0" class="col_heading level0 col0" >C</th>
#       <th id="T_a3efe_level0_col1" class="col_heading level0 col1" >D</th>
#       <th id="T_a3efe_level0_col2" class="col_heading level0 col2" >E</th>
#       <th id="T_a3efe_level0_col3" class="col_heading level0 col3" >F</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_a3efe_level0_row0" class="row_heading level0 row0" >2</th>
#       <td id="T_a3efe_row0_col0" class="data row0 col0" >RC2</td>
#       <td id="T_a3efe_row0_col1" class="data row0 col1" >RD2</td>
#       <td id="T_a3efe_row0_col2" class="data row0 col2" >RE2</td>
#       <td id="T_a3efe_row0_col3" class="data row0 col3" >RF2</td>
#     </tr>
#     <tr>
#       <th id="T_a3efe_level0_row1" class="row_heading level0 row1" >3</th>
#       <td id="T_a3efe_row1_col0" class="data row1 col0" >RC3</td>
#       <td id="T_a3efe_row1_col1" class="data row1 col1" >RD3</td>
#       <td id="T_a3efe_row1_col2" class="data row1 col2" >RE3</td>
#       <td id="T_a3efe_row1_col3" class="data row1 col3" >RF3</td>
#     </tr>
#     <tr>
#       <th id="T_a3efe_level0_row2" class="row_heading level0 row2" >4</th>
#       <td id="T_a3efe_row2_col0" class="data row2 col0" >RC4</td>
#       <td id="T_a3efe_row2_col1" class="data row2 col1" >RD4</td>
#       <td id="T_a3efe_row2_col2" class="data row2 col2" >RE4</td>
#       <td id="T_a3efe_row2_col3" class="data row2 col3" >RF4</td>
#     </tr>
#     <tr>
#       <th id="T_a3efe_level0_row3" class="row_heading level0 row3" >5</th>
#       <td id="T_a3efe_row3_col0" class="data row3 col0" >RC5</td>
#       <td id="T_a3efe_row3_col1" class="data row3 col1" >RD5</td>
#       <td id="T_a3efe_row3_col2" class="data row3 col2" >RE5</td>
#       <td id="T_a3efe_row3_col3" class="data row3 col3" >RF5</td>
#     </tr>
#   </tbody>
# </table>

# %%
# Lect 1, 22 min:
pd.concat([left, right]) # axis='index' är default.
# Out:
#      A    B    C    D    E    F
# 0  LA0  LB0  LC0  LD0  NaN  NaN
# 1  LA1  LB1  LC1  LD1  NaN  NaN
# 2  LA2  LB2  LC2  LD2  NaN  NaN
# 3  LA3  LB3  LC3  LD3  NaN  NaN
# 2  NaN  NaN  RC2  RD2  RE2  RF2
# 3  NaN  NaN  RC3  RD3  RE3  RF3
# 4  NaN  NaN  RC4  RD4  RE4  RF4
# 5  NaN  NaN  RC5  RD5  RE5  RF5

# %%
pd.concat([left, right], axis='columns')
# Out:
#      A    B    C    D    C    D    E    F
# 0  LA0  LB0  LC0  LD0  NaN  NaN  NaN  NaN
# 1  LA1  LB1  LC1  LD1  NaN  NaN  NaN  NaN
# 2  LA2  LB2  LC2  LD2  RC2  RD2  RE2  RF2
# 3  LA3  LB3  LC3  LD3  RC3  RD3  RE3  RF3
# 4  NaN  NaN  NaN  NaN  RC4  RD4  RE4  RF4
# 5  NaN  NaN  NaN  NaN  RC5  RD5  RE5  RF5

# %%
hdisplay([
    pd.concat([left, right]),
    pd.concat([left, right], axis='columns', join='outer'), #liknande set union, 'outer' är default
    pd.concat([left, right], axis='columns', join='inner')], #liknadne set intersection
    ["axis='index'","axis='columns', join='outer'","axis='columns', join='inner'"],
    20
    )
# Out:
# <style type="text/css">
# #T_a9edf th {
#   text-align: left;
#   vertical-align: top;
# }
# </style>
# <table id="T_a9edf" style='display:inline; margin-right: 20px;'>
#   <caption>axis='index'</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_a9edf_level0_col0" class="col_heading level0 col0" >A</th>
#       <th id="T_a9edf_level0_col1" class="col_heading level0 col1" >B</th>
#       <th id="T_a9edf_level0_col2" class="col_heading level0 col2" >C</th>
#       <th id="T_a9edf_level0_col3" class="col_heading level0 col3" >D</th>
#       <th id="T_a9edf_level0_col4" class="col_heading level0 col4" >E</th>
#       <th id="T_a9edf_level0_col5" class="col_heading level0 col5" >F</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_a9edf_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_a9edf_row0_col0" class="data row0 col0" >LA0</td>
#       <td id="T_a9edf_row0_col1" class="data row0 col1" >LB0</td>
#       <td id="T_a9edf_row0_col2" class="data row0 col2" >LC0</td>
#       <td id="T_a9edf_row0_col3" class="data row0 col3" >LD0</td>
#       <td id="T_a9edf_row0_col4" class="data row0 col4" >nan</td>
#       <td id="T_a9edf_row0_col5" class="data row0 col5" >nan</td>
#     </tr>
#     <tr>
#       <th id="T_a9edf_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_a9edf_row1_col0" class="data row1 col0" >LA1</td>
#       <td id="T_a9edf_row1_col1" class="data row1 col1" >LB1</td>
#       <td id="T_a9edf_row1_col2" class="data row1 col2" >LC1</td>
#       <td id="T_a9edf_row1_col3" class="data row1 col3" >LD1</td>
#       <td id="T_a9edf_row1_col4" class="data row1 col4" >nan</td>
#       <td id="T_a9edf_row1_col5" class="data row1 col5" >nan</td>
#     </tr>
#     <tr>
#       <th id="T_a9edf_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_a9edf_row2_col0" class="data row2 col0" >LA2</td>
#       <td id="T_a9edf_row2_col1" class="data row2 col1" >LB2</td>
#       <td id="T_a9edf_row2_col2" class="data row2 col2" >LC2</td>
#       <td id="T_a9edf_row2_col3" class="data row2 col3" >LD2</td>
#       <td id="T_a9edf_row2_col4" class="data row2 col4" >nan</td>
#       <td id="T_a9edf_row2_col5" class="data row2 col5" >nan</td>
#     </tr>
#     <tr>
#       <th id="T_a9edf_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_a9edf_row3_col0" class="data row3 col0" >LA3</td>
#       <td id="T_a9edf_row3_col1" class="data row3 col1" >LB3</td>
#       <td id="T_a9edf_row3_col2" class="data row3 col2" >LC3</td>
#       <td id="T_a9edf_row3_col3" class="data row3 col3" >LD3</td>
#       <td id="T_a9edf_row3_col4" class="data row3 col4" >nan</td>
#       <td id="T_a9edf_row3_col5" class="data row3 col5" >nan</td>
#     </tr>
#     <tr>
#       <th id="T_a9edf_level0_row4" class="row_heading level0 row4" >2</th>
#       <td id="T_a9edf_row4_col0" class="data row4 col0" >nan</td>
#       <td id="T_a9edf_row4_col1" class="data row4 col1" >nan</td>
#       <td id="T_a9edf_row4_col2" class="data row4 col2" >RC2</td>
#       <td id="T_a9edf_row4_col3" class="data row4 col3" >RD2</td>
#       <td id="T_a9edf_row4_col4" class="data row4 col4" >RE2</td>
#       <td id="T_a9edf_row4_col5" class="data row4 col5" >RF2</td>
#     </tr>
#     <tr>
#       <th id="T_a9edf_level0_row5" class="row_heading level0 row5" >3</th>
#       <td id="T_a9edf_row5_col0" class="data row5 col0" >nan</td>
#       <td id="T_a9edf_row5_col1" class="data row5 col1" >nan</td>
#       <td id="T_a9edf_row5_col2" class="data row5 col2" >RC3</td>
#       <td id="T_a9edf_row5_col3" class="data row5 col3" >RD3</td>
#       <td id="T_a9edf_row5_col4" class="data row5 col4" >RE3</td>
#       <td id="T_a9edf_row5_col5" class="data row5 col5" >RF3</td>
#     </tr>
#     <tr>
#       <th id="T_a9edf_level0_row6" class="row_heading level0 row6" >4</th>
#       <td id="T_a9edf_row6_col0" class="data row6 col0" >nan</td>
#       <td id="T_a9edf_row6_col1" class="data row6 col1" >nan</td>
#       <td id="T_a9edf_row6_col2" class="data row6 col2" >RC4</td>
#       <td id="T_a9edf_row6_col3" class="data row6 col3" >RD4</td>
#       <td id="T_a9edf_row6_col4" class="data row6 col4" >RE4</td>
#       <td id="T_a9edf_row6_col5" class="data row6 col5" >RF4</td>
#     </tr>
#     <tr>
#       <th id="T_a9edf_level0_row7" class="row_heading level0 row7" >5</th>
#       <td id="T_a9edf_row7_col0" class="data row7 col0" >nan</td>
#       <td id="T_a9edf_row7_col1" class="data row7 col1" >nan</td>
#       <td id="T_a9edf_row7_col2" class="data row7 col2" >RC5</td>
#       <td id="T_a9edf_row7_col3" class="data row7 col3" >RD5</td>
#       <td id="T_a9edf_row7_col4" class="data row7 col4" >RE5</td>
#       <td id="T_a9edf_row7_col5" class="data row7 col5" >RF5</td>
#     </tr>
#   </tbody>
# </table>
# <style type="text/css">
# #T_4218f th {
#   text-align: left;
#   vertical-align: top;
# }
# </style>
# <table id="T_4218f" style='display:inline; margin-right: 20px;'>
#   <caption>axis='columns', join='outer'</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_4218f_level0_col0" class="col_heading level0 col0" >A</th>
#       <th id="T_4218f_level0_col1" class="col_heading level0 col1" >B</th>
#       <th id="T_4218f_level0_col2" class="col_heading level0 col2" >C</th>
#       <th id="T_4218f_level0_col3" class="col_heading level0 col3" >D</th>
#       <th id="T_4218f_level0_col4" class="col_heading level0 col4" >C</th>
#       <th id="T_4218f_level0_col5" class="col_heading level0 col5" >D</th>
#       <th id="T_4218f_level0_col6" class="col_heading level0 col6" >E</th>
#       <th id="T_4218f_level0_col7" class="col_heading level0 col7" >F</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_4218f_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_4218f_row0_col0" class="data row0 col0" >LA0</td>
#       <td id="T_4218f_row0_col1" class="data row0 col1" >LB0</td>
#       <td id="T_4218f_row0_col2" class="data row0 col2" >LC0</td>
#       <td id="T_4218f_row0_col3" class="data row0 col3" >LD0</td>
#       <td id="T_4218f_row0_col4" class="data row0 col4" >nan</td>
#       <td id="T_4218f_row0_col5" class="data row0 col5" >nan</td>
#       <td id="T_4218f_row0_col6" class="data row0 col6" >nan</td>
#       <td id="T_4218f_row0_col7" class="data row0 col7" >nan</td>
#     </tr>
#     <tr>
#       <th id="T_4218f_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_4218f_row1_col0" class="data row1 col0" >LA1</td>
#       <td id="T_4218f_row1_col1" class="data row1 col1" >LB1</td>
#       <td id="T_4218f_row1_col2" class="data row1 col2" >LC1</td>
#       <td id="T_4218f_row1_col3" class="data row1 col3" >LD1</td>
#       <td id="T_4218f_row1_col4" class="data row1 col4" >nan</td>
#       <td id="T_4218f_row1_col5" class="data row1 col5" >nan</td>
#       <td id="T_4218f_row1_col6" class="data row1 col6" >nan</td>
#       <td id="T_4218f_row1_col7" class="data row1 col7" >nan</td>
#     </tr>
#     <tr>
#       <th id="T_4218f_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_4218f_row2_col0" class="data row2 col0" >LA2</td>
#       <td id="T_4218f_row2_col1" class="data row2 col1" >LB2</td>
#       <td id="T_4218f_row2_col2" class="data row2 col2" >LC2</td>
#       <td id="T_4218f_row2_col3" class="data row2 col3" >LD2</td>
#       <td id="T_4218f_row2_col4" class="data row2 col4" >RC2</td>
#       <td id="T_4218f_row2_col5" class="data row2 col5" >RD2</td>
#       <td id="T_4218f_row2_col6" class="data row2 col6" >RE2</td>
#       <td id="T_4218f_row2_col7" class="data row2 col7" >RF2</td>
#     </tr>
#     <tr>
#       <th id="T_4218f_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_4218f_row3_col0" class="data row3 col0" >LA3</td>
#       <td id="T_4218f_row3_col1" class="data row3 col1" >LB3</td>
#       <td id="T_4218f_row3_col2" class="data row3 col2" >LC3</td>
#       <td id="T_4218f_row3_col3" class="data row3 col3" >LD3</td>
#       <td id="T_4218f_row3_col4" class="data row3 col4" >RC3</td>
#       <td id="T_4218f_row3_col5" class="data row3 col5" >RD3</td>
#       <td id="T_4218f_row3_col6" class="data row3 col6" >RE3</td>
#       <td id

# %% [markdown]
# parameter 'keys':
# - ett sätt att concatenera ihop dataframes, men samtidigt hålla reda på vad som kommer från vilken ursprunglig dataframe.
# - man kan återskapa de ursprungliga DF'arna

# %%
pd.concat([left, right], keys=['left','right'])
# Out:
#            A    B    C    D    E    F
# left  0  LA0  LB0  LC0  LD0  NaN  NaN
#       1  LA1  LB1  LC1  LD1  NaN  NaN
#       2  LA2  LB2  LC2  LD2  NaN  NaN
#       3  LA3  LB3  LC3  LD3  NaN  NaN
# right 2  NaN  NaN  RC2  RD2  RE2  RF2
#       3  NaN  NaN  RC3  RD3  RE3  RF3
#       4  NaN  NaN  RC4  RD4  RE4  RF4
#       5  NaN  NaN  RC5  RD5  RE5  RF5

# %%
hdisplay([pd.concat([left, right], axis='index', keys=['left','right']),
          pd.concat([left, right], axis='columns', keys=['left','right'])],
          ["axis='index, keys=['left','right]","axis='columns', keys=['left','right']"]
)
# Out:
# <style type="text/css">
# #T_0aad2 th {
#   text-align: left;
#   vertical-align: top;
# }
# </style>
# <table id="T_0aad2" style='display:inline; margin-right: 50px;'>
#   <caption>axis='index, keys=['left','right]</caption>
#   <thead>
#     <tr>
#       <th class="blank" >&nbsp;</th>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_0aad2_level0_col0" class="col_heading level0 col0" >A</th>
#       <th id="T_0aad2_level0_col1" class="col_heading level0 col1" >B</th>
#       <th id="T_0aad2_level0_col2" class="col_heading level0 col2" >C</th>
#       <th id="T_0aad2_level0_col3" class="col_heading level0 col3" >D</th>
#       <th id="T_0aad2_level0_col4" class="col_heading level0 col4" >E</th>
#       <th id="T_0aad2_level0_col5" class="col_heading level0 col5" >F</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_0aad2_level0_row0" class="row_heading level0 row0" rowspan="4">left</th>
#       <th id="T_0aad2_level1_row0" class="row_heading level1 row0" >0</th>
#       <td id="T_0aad2_row0_col0" class="data row0 col0" >LA0</td>
#       <td id="T_0aad2_row0_col1" class="data row0 col1" >LB0</td>
#       <td id="T_0aad2_row0_col2" class="data row0 col2" >LC0</td>
#       <td id="T_0aad2_row0_col3" class="data row0 col3" >LD0</td>
#       <td id="T_0aad2_row0_col4" class="data row0 col4" >nan</td>
#       <td id="T_0aad2_row0_col5" class="data row0 col5" >nan</td>
#     </tr>
#     <tr>
#       <th id="T_0aad2_level1_row1" class="row_heading level1 row1" >1</th>
#       <td id="T_0aad2_row1_col0" class="data row1 col0" >LA1</td>
#       <td id="T_0aad2_row1_col1" class="data row1 col1" >LB1</td>
#       <td id="T_0aad2_row1_col2" class="data row1 col2" >LC1</td>
#       <td id="T_0aad2_row1_col3" class="data row1 col3" >LD1</td>
#       <td id="T_0aad2_row1_col4" class="data row1 col4" >nan</td>
#       <td id="T_0aad2_row1_col5" class="data row1 col5" >nan</td>
#     </tr>
#     <tr>
#       <th id="T_0aad2_level1_row2" class="row_heading level1 row2" >2</th>
#       <td id="T_0aad2_row2_col0" class="data row2 col0" >LA2</td>
#       <td id="T_0aad2_row2_col1" class="data row2 col1" >LB2</td>
#       <td id="T_0aad2_row2_col2" class="data row2 col2" >LC2</td>
#       <td id="T_0aad2_row2_col3" class="data row2 col3" >LD2</td>
#       <td id="T_0aad2_row2_col4" class="data row2 col4" >nan</td>
#       <td id="T_0aad2_row2_col5" class="data row2 col5" >nan</td>
#     </tr>
#     <tr>
#       <th id="T_0aad2_level1_row3" class="row_heading level1 row3" >3</th>
#       <td id="T_0aad2_row3_col0" class="data row3 col0" >LA3</td>
#       <td id="T_0aad2_row3_col1" class="data row3 col1" >LB3</td>
#       <td id="T_0aad2_row3_col2" class="data row3 col2" >LC3</td>
#       <td id="T_0aad2_row3_col3" class="data row3 col3" >LD3</td>
#       <td id="T_0aad2_row3_col4" class="data row3 col4" >nan</td>
#       <td id="T_0aad2_row3_col5" class="data row3 col5" >nan</td>
#     </tr>
#     <tr>
#       <th id="T_0aad2_level0_row4" class="row_heading level0 row4" rowspan="4">right</th>
#       <th id="T_0aad2_level1_row4" class="row_heading level1 row4" >2</th>
#       <td id="T_0aad2_row4_col0" class="data row4 col0" >nan</td>
#       <td id="T_0aad2_row4_col1" class="data row4 col1" >nan</td>
#       <td id="T_0aad2_row4_col2" class="data row4 col2" >RC2</td>
#       <td id="T_0aad2_row4_col3" class="data row4 col3" >RD2</td>
#       <td id="T_0aad2_row4_col4" class="data row4 col4" >RE2</td>
#       <td id="T_0aad2_row4_col5" class="data row4 col5" >RF2</td>
#     </tr>
#     <tr>
#       <th id="T_0aad2_level1_row5" class="row_heading level1 row5" >3</th>
#       <td id="T_0aad2_row5_col0" class="data row5 col0" >nan</td>
#       <td id="T_0aad2_row5_col1" class="data row5 col1" >nan</td>
#       <td id="T_0aad2_row5_col2" class="data row5 col2" >RC3</td>
#       <td id="T_0aad2_row5_col3" class="data row5 col3" >RD3</td>
#       <td id="T_0aad2_row5_col4" class="data row5 col4" >RE3</td>
#       <td id="T_0aad2_row5_col5" class="data row5 col5" >RF3</td>
#     </tr>
#     <tr>
#       <th id="T_0aad2_level1_row6" class="row_heading level1 row6" >4</th>
#       <td id="T_0aad2_row6_col0" class="data row6 col0" >nan</td>
#       <td id="T_0aad2_row6_col1" class="data row6 col1" >nan</td>
#       <td id="T_0aad2_row6_col2" class="data row6 col2" >RC4</td>
#       <td id="T_0aad2_row6_col3" class="data row6 col3" >RD4</td>
#       <td id="T_0aad2_row6_col4" class="data row6 col4" >RE4</td>
#       <td id="T_0aad2_row6_col5" class="data row6 col5" >RF4</td>
#     </tr>
#     <tr>
#       <th id="T_0aad2_level1_row7" class="row_heading level1 row7" >5</th>
#       <td id="T_0aad2_row7_col0" class="data row7 col0" >nan</td>
#       <td id="T_0aad2_row7_col1" class="data row7 col1" >nan</td>
#       <td id="T_0aad2_row7_col2" class="data row7 col2" >RC5</td>
#       <td id="T_0aad2_row7_col3" class="data row7 col3" >RD5</td>
#       <td id="T_0aad2_row7_col4" class="data row7 col4" >RE5</td>
#       <td id="T_0aad2_row7_col5" class="data row7 col5" >RF5</td>
#     </tr>
#   </tbody>
# </table>
# <style type="text/css">
# #T_ca9a0 th {
#   text-align: left;
#   vertical-align: top;
# }
# </style>
# <table id="T_ca9a0" style='display:inline; margin-right: 50px;'>
#   <caption>axis='columns', keys=['left','right']</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_ca9a0_level0_col0" class="col_heading level0 col0" colspan="4">left</th>
#       <th id="T_ca9a0_level0_col4" class="col_heading level0 col4" colspan="4">right</th>
#     </tr>
#     <tr>
#       <th class="blank level1" >&nbsp;</th>
#       <th id="T_ca9a0_level1_col0" class="col_heading level1 col0" >A</th>
#       <th id="T_ca9a0_level1_col1" class="col_heading level1 col1" >B</th>
#       <th id="T_ca9a0_level1_col2" class="col_heading level1 col2" >C</th>
#       <th id="T_ca9a0_level1_col3" class="col_heading level1 col3" >D</th>
#       <th id="T_ca9a0_level1_col4" class="col_heading level1 col4" >C</th>
#       <th id="T_ca9a0_level1_col5" class="col_heading level1 col5" >D</th>
#       <th id="T_ca9a0_level1_col6" class="col_heading level1 col6" >E</th>
#       <th id="T_ca9a0_level1_col7" class="col_heading level1 col7" >F</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_ca9a0_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_ca9a0_row0_col0" class="data row0 col0" >LA0</td>
#       <td id="T_ca9a0_row0_col1" class="data row0 col1" >LB0</td>
#       <td id="T_ca9a0_row0_col2" class="data row0 col2" >LC0</td>
#       <td id="T_ca9a0_row0_col3" class="data row0 col3" >LD0</td>
#       <td id="T_ca9a0_row0_col4" class="data row0 col4" >nan</td>
#       <td id="T_ca9a0_row0_col5" class="data row0 col5" >nan</td>
#       <td id="T_ca9a0_row0_col6" class="data row0 col6" >nan</td>
#       <td id="T_ca9a0_row0_col7" class="data row0 col7" >nan</td>
#     </tr>
#     <tr>
#       <th id="T_ca9a0_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_ca9a0_row1_col0" class="data row1 col0" >LA1</td>
#       <td id="T_ca9a0_row1_col1" class="data row1 col1" >LB1</td>
#       <td id="T_ca9a0_row1_col2" class="data row1 col2" >LC1</td>
#       <td id="T_ca9a0_row1_col3" class="data row1 col3" >LD1</td>
#       <td id="T_ca9a0_row1_col4" class="data row1 col4" >nan</td>
#       <td id="T_ca9a0_row1_col5" class="data row1 col5" >nan</td>
#       <td id="T_ca9a0_row1_col6" class="data row1 col6" >nan</td>
#       <td id="T_ca9a0_row1_col7" class="data row1 col7" >nan</td>
#     </tr>
#     <tr>
#       <th id="T_ca9a0_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_ca9a0_row2_col0" class="data row2 col0" >LA2</td>
#       <td id="T_ca9a0_row2_col1" class="data row2 col1" >LB2</td>
#       <td id="T_ca9a0_row2_col2" class="data row2 col2" >LC2</td>
#       <td id="T_ca9a0_row2_col3" class="data row2 col3" >LD2</td>
#       <td id="T_ca9a0_row2_col4" class="data row2 col4" >RC2</td>
#       <td id="T_ca9a0_row2_col5" class="data row2 col5" >RD2</td>
#       <td id="T_ca9a0_row2_col6" class="data row2 col6" >RE2</td>
#       <td id="T_ca9a0_row2_col7" class="data row2 col7" >RF2</td>
#     </tr>
#     <tr>
#       <th id="T_ca9a0_level0_row3" class="row_heading level0

# %% [markdown]
# ## Join
# - Join first aligns the indices of two dataframes, and then pick up the remaining columns from the aligned rows of each dataframe.
# - Parameters:
#     - how can be any of following:
#         - **'left'** = get all rows from the left table and join matching rows from right table (=default)
#         - **'right'** = get all rows from the right table and join matching rows from left table
#         - **'outer'** = get all rows from all tables and join matching rows on both sides (liknande 'union')
#         - **'inner'** = get all rows that exist in both tables. (intersection)
#         - **'cross'** = Get every possible combination of rows from both tables. Length of new table == len(left) * len(right)
#         OVAN ÄR VÄLDIGT LIKT SQL

# %%
# New sample data

left = sample_df("A0","D3", prefix="L")
right = sample_df("C2","F5", prefix="R")
hdisplay([left, right],['Left','Right'])
# Out:
# <style type="text/css">
# #T_16e95 th {
#   text-align: left;
#   vertical-align: top;
# }
# </style>
# <table id="T_16e95" style='display:inline; margin-right: 50px;'>
#   <caption>Left</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_16e95_level0_col0" class="col_heading level0 col0" >A</th>
#       <th id="T_16e95_level0_col1" class="col_heading level0 col1" >B</th>
#       <th id="T_16e95_level0_col2" class="col_heading level0 col2" >C</th>
#       <th id="T_16e95_level0_col3" class="col_heading level0 col3" >D</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_16e95_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_16e95_row0_col0" class="data row0 col0" >LA0</td>
#       <td id="T_16e95_row0_col1" class="data row0 col1" >LB0</td>
#       <td id="T_16e95_row0_col2" class="data row0 col2" >LC0</td>
#       <td id="T_16e95_row0_col3" class="data row0 col3" >LD0</td>
#     </tr>
#     <tr>
#       <th id="T_16e95_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_16e95_row1_col0" class="data row1 col0" >LA1</td>
#       <td id="T_16e95_row1_col1" class="data row1 col1" >LB1</td>
#       <td id="T_16e95_row1_col2" class="data row1 col2" >LC1</td>
#       <td id="T_16e95_row1_col3" class="data row1 col3" >LD1</td>
#     </tr>
#     <tr>
#       <th id="T_16e95_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_16e95_row2_col0" class="data row2 col0" >LA2</td>
#       <td id="T_16e95_row2_col1" class="data row2 col1" >LB2</td>
#       <td id="T_16e95_row2_col2" class="data row2 col2" >LC2</td>
#       <td id="T_16e95_row2_col3" class="data row2 col3" >LD2</td>
#     </tr>
#     <tr>
#       <th id="T_16e95_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_16e95_row3_col0" class="data row3 col0" >LA3</td>
#       <td id="T_16e95_row3_col1" class="data row3 col1" >LB3</td>
#       <td id="T_16e95_row3_col2" class="data row3 col2" >LC3</td>
#       <td id="T_16e95_row3_col3" class="data row3 col3" >LD3</td>
#     </tr>
#   </tbody>
# </table>
# <style type="text/css">
# #T_59c2b th {
#   text-align: left;
#   vertical-align: top;
# }
# </style>
# <table id="T_59c2b" style='display:inline; margin-right: 50px;'>
#   <caption>Right</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_59c2b_level0_col0" class="col_heading level0 col0" >C</th>
#       <th id="T_59c2b_level0_col1" class="col_heading level0 col1" >D</th>
#       <th id="T_59c2b_level0_col2" class="col_heading level0 col2" >E</th>
#       <th id="T_59c2b_level0_col3" class="col_heading level0 col3" >F</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_59c2b_level0_row0" class="row_heading level0 row0" >2</th>
#       <td id="T_59c2b_row0_col0" class="data row0 col0" >RC2</td>
#       <td id="T_59c2b_row0_col1" class="data row0 col1" >RD2</td>
#       <td id="T_59c2b_row0_col2" class="data row0 col2" >RE2</td>
#       <td id="T_59c2b_row0_col3" class="data row0 col3" >RF2</td>
#     </tr>
#     <tr>
#       <th id="T_59c2b_level0_row1" class="row_heading level0 row1" >3</th>
#       <td id="T_59c2b_row1_col0" class="data row1 col0" >RC3</td>
#       <td id="T_59c2b_row1_col1" class="data row1 col1" >RD3</td>
#       <td id="T_59c2b_row1_col2" class="data row1 col2" >RE3</td>
#       <td id="T_59c2b_row1_col3" class="data row1 col3" >RF3</td>
#     </tr>
#     <tr>
#       <th id="T_59c2b_level0_row2" class="row_heading level0 row2" >4</th>
#       <td id="T_59c2b_row2_col0" class="data row2 col0" >RC4</td>
#       <td id="T_59c2b_row2_col1" class="data row2 col1" >RD4</td>
#       <td id="T_59c2b_row2_col2" class="data row2 col2" >RE4</td>
#       <td id="T_59c2b_row2_col3" class="data row2 col3" >RF4</td>
#     </tr>
#     <tr>
#       <th id="T_59c2b_level0_row3" class="row_heading level0 row3" >5</th>
#       <td id="T_59c2b_row3_col0" class="data row3 col0" >RC5</td>
#       <td id="T_59c2b_row3_col1" class="data row3 col1" >RD5</td>
#       <td id="T_59c2b_row3_col2" class="data row3 col2" >RE5</td>
#       <td id="T_59c2b_row3_col3" class="data row3 col3" >RF5</td>
#     </tr>
#   </tbody>
# </table>

# %%
left.join(right, lsuffix="_L", rsuffix="_R") # så man inte får dubletter på kolumnerna
# Out:
#      A    B  C_L  D_L  C_R  D_R    E    F
# 0  LA0  LB0  LC0  LD0  NaN  NaN  NaN  NaN
# 1  LA1  LB1  LC1  LD1  NaN  NaN  NaN  NaN
# 2  LA2  LB2  LC2  LD2  RC2  RD2  RE2  RF2
# 3  LA3  LB3  LC3  LD3  RC3  RD3  RE3  RF3

# %%
# New sample data again, adderar suffix på alla cols så det inte finns gemensamma

left = sample_df("A0","D3", prefix="L").add_prefix('L')
right = sample_df("C2","F5", prefix="R").add_prefix('R')
hdisplay([left, right],['Left','Right'])
# Out:
# <style type="text/css">
# #T_372e2 th {
#   text-align: left;
#   vertical-align: top;
# }
# </style>
# <table id="T_372e2" style='display:inline; margin-right: 50px;'>
#   <caption>Left</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_372e2_level0_col0" class="col_heading level0 col0" >LA</th>
#       <th id="T_372e2_level0_col1" class="col_heading level0 col1" >LB</th>
#       <th id="T_372e2_level0_col2" class="col_heading level0 col2" >LC</th>
#       <th id="T_372e2_level0_col3" class="col_heading level0 col3" >LD</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_372e2_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_372e2_row0_col0" class="data row0 col0" >LA0</td>
#       <td id="T_372e2_row0_col1" class="data row0 col1" >LB0</td>
#       <td id="T_372e2_row0_col2" class="data row0 col2" >LC0</td>
#       <td id="T_372e2_row0_col3" class="data row0 col3" >LD0</td>
#     </tr>
#     <tr>
#       <th id="T_372e2_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_372e2_row1_col0" class="data row1 col0" >LA1</td>
#       <td id="T_372e2_row1_col1" class="data row1 col1" >LB1</td>
#       <td id="T_372e2_row1_col2" class="data row1 col2" >LC1</td>
#       <td id="T_372e2_row1_col3" class="data row1 col3" >LD1</td>
#     </tr>
#     <tr>
#       <th id="T_372e2_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_372e2_row2_col0" class="data row2 col0" >LA2</td>
#       <td id="T_372e2_row2_col1" class="data row2 col1" >LB2</td>
#       <td id="T_372e2_row2_col2" class="data row2 col2" >LC2</td>
#       <td id="T_372e2_row2_col3" class="data row2 col3" >LD2</td>
#     </tr>
#     <tr>
#       <th id="T_372e2_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_372e2_row3_col0" class="data row3 col0" >LA3</td>
#       <td id="T_372e2_row3_col1" class="data row3 col1" >LB3</td>
#       <td id="T_372e2_row3_col2" class="data row3 col2" >LC3</td>
#       <td id="T_372e2_row3_col3" class="data row3 col3" >LD3</td>
#     </tr>
#   </tbody>
# </table>
# <style type="text/css">
# #T_61cb1 th {
#   text-align: left;
#   vertical-align: top;
# }
# </style>
# <table id="T_61cb1" style='display:inline; margin-right: 50px;'>
#   <caption>Right</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_61cb1_level0_col0" class="col_heading level0 col0" >RC</th>
#       <th id="T_61cb1_level0_col1" class="col_heading level0 col1" >RD</th>
#       <th id="T_61cb1_level0_col2" class="col_heading level0 col2" >RE</th>
#       <th id="T_61cb1_level0_col3" class="col_heading level0 col3" >RF</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_61cb1_level0_row0" class="row_heading level0 row0" >2</th>
#       <td id="T_61cb1_row0_col0" class="data row0 col0" >RC2</td>
#       <td id="T_61cb1_row0_col1" class="data row0 col1" >RD2</td>
#       <td id="T_61cb1_row0_col2" class="data row0 col2" >RE2</td>
#       <td id="T_61cb1_row0_col3" class="data row0 col3" >RF2</td>
#     </tr>
#     <tr>
#       <th id="T_61cb1_level0_row1" class="row_heading level0 row1" >3</th>
#       <td id="T_61cb1_row1_col0" class="data row1 col0" >RC3</td>
#       <td id="T_61cb1_row1_col1" class="data row1 col1" >RD3</td>
#       <td id="T_61cb1_row1_col2" class="data row1 col2" >RE3</td>
#       <td id="T_61cb1_row1_col3" class="data row1 col3" >RF3</td>
#     </tr>
#     <tr>
#       <th id="T_61cb1_level0_row2" class="row_heading level0 row2" >4</th>
#       <td id="T_61cb1_row2_col0" class="data row2 col0" >RC4</td>
#       <td id="T_61cb1_row2_col1" class="data row2 col1" >RD4</td>
#       <td id="T_61cb1_row2_col2" class="data row2 col2" >RE4</td>
#       <td id="T_61cb1_row2_col3" class="data row2 col3" >RF4</td>
#     </tr>
#     <tr>
#       <th id="T_61cb1_level0_row3" class="row_heading level0 row3" >5</th>
#       <td id="T_61cb1_row3_col0" class="data row3 col0" >RC5</td>
#       <td id="T_61cb1_row3_col1" class="data row3 col1" >RD5</td>
#       <td id="T_61cb1_row3_col2" class="data row3 col2" >RE5</td>
#       <td id="T_61cb1_row3_col3" class="data row3 col3" >RF5</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ##### Join parameter 'how'
# Om man skriver "how='left'" får man med alla raderna från 'left', och joinar in alla gemensamma rader från 'right'.

# %%
hdisplay([left.join(right, how='left'),
          left.join(right, how='right')],
          ["how='left'","how='right"]
          )
# Out:
# <style type="text/css">
# #T_d0f58 th {
#   text-align: left;
#   vertical-align: top;
# }
# </style>
# <table id="T_d0f58" style='display:inline; margin-right: 50px;'>
#   <caption>how='left'</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_d0f58_level0_col0" class="col_heading level0 col0" >LA</th>
#       <th id="T_d0f58_level0_col1" class="col_heading level0 col1" >LB</th>
#       <th id="T_d0f58_level0_col2" class="col_heading level0 col2" >LC</th>
#       <th id="T_d0f58_level0_col3" class="col_heading level0 col3" >LD</th>
#       <th id="T_d0f58_level0_col4" class="col_heading level0 col4" >RC</th>
#       <th id="T_d0f58_level0_col5" class="col_heading level0 col5" >RD</th>
#       <th id="T_d0f58_level0_col6" class="col_heading level0 col6" >RE</th>
#       <th id="T_d0f58_level0_col7" class="col_heading level0 col7" >RF</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_d0f58_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_d0f58_row0_col0" class="data row0 col0" >LA0</td>
#       <td id="T_d0f58_row0_col1" class="data row0 col1" >LB0</td>
#       <td id="T_d0f58_row0_col2" class="data row0 col2" >LC0</td>
#       <td id="T_d0f58_row0_col3" class="data row0 col3" >LD0</td>
#       <td id="T_d0f58_row0_col4" class="data row0 col4" >nan</td>
#       <td id="T_d0f58_row0_col5" class="data row0 col5" >nan</td>
#       <td id="T_d0f58_row0_col6" class="data row0 col6" >nan</td>
#       <td id="T_d0f58_row0_col7" class="data row0 col7" >nan</td>
#     </tr>
#     <tr>
#       <th id="T_d0f58_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_d0f58_row1_col0" class="data row1 col0" >LA1</td>
#       <td id="T_d0f58_row1_col1" class="data row1 col1" >LB1</td>
#       <td id="T_d0f58_row1_col2" class="data row1 col2" >LC1</td>
#       <td id="T_d0f58_row1_col3" class="data row1 col3" >LD1</td>
#       <td id="T_d0f58_row1_col4" class="data row1 col4" >nan</td>
#       <td id="T_d0f58_row1_col5" class="data row1 col5" >nan</td>
#       <td id="T_d0f58_row1_col6" class="data row1 col6" >nan</td>
#       <td id="T_d0f58_row1_col7" class="data row1 col7" >nan</td>
#     </tr>
#     <tr>
#       <th id="T_d0f58_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_d0f58_row2_col0" class="data row2 col0" >LA2</td>
#       <td id="T_d0f58_row2_col1" class="data row2 col1" >LB2</td>
#       <td id="T_d0f58_row2_col2" class="data row2 col2" >LC2</td>
#       <td id="T_d0f58_row2_col3" class="data row2 col3" >LD2</td>
#       <td id="T_d0f58_row2_col4" class="data row2 col4" >RC2</td>
#       <td id="T_d0f58_row2_col5" class="data row2 col5" >RD2</td>
#       <td id="T_d0f58_row2_col6" class="data row2 col6" >RE2</td>
#       <td id="T_d0f58_row2_col7" class="data row2 col7" >RF2</td>
#     </tr>
#     <tr>
#       <th id="T_d0f58_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_d0f58_row3_col0" class="data row3 col0" >LA3</td>
#       <td id="T_d0f58_row3_col1" class="data row3 col1" >LB3</td>
#       <td id="T_d0f58_row3_col2" class="data row3 col2" >LC3</td>
#       <td id="T_d0f58_row3_col3" class="data row3 col3" >LD3</td>
#       <td id="T_d0f58_row3_col4" class="data row3 col4" >RC3</td>
#       <td id="T_d0f58_row3_col5" class="data row3 col5" >RD3</td>
#       <td id="T_d0f58_row3_col6" class="data row3 col6" >RE3</td>
#       <td id="T_d0f58_row3_col7" class="data row3 col7" >RF3</td>
#     </tr>
#   </tbody>
# </table>
# <style type="text/css">
# #T_90892 th {
#   text-align: left;
#   vertical-align: top;
# }
# </style>
# <table id="T_90892" style='display:inline; margin-right: 50px;'>
#   <caption>how='right</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_90892_level0_col0" class="col_heading level0 col0" >LA</th>
#       <th id="T_90892_level0_col1" class="col_heading level0 col1" >LB</th>
#       <th id="T_90892_level0_col2" class="col_heading level0 col2" >LC</th>
#       <th id="T_90892_level0_col3" class="col_heading level0 col3" >LD</th>
#       <th id="T_90892_level0_col4" class="col_heading level0 col4" >RC</th>
#       <th id="T_90892_level0_col5" class="col_heading level0 col5" >RD</th>
#       <th id="T_90892_level0_col6" class="col_heading level0 col6" >RE</th>
#       <th id="T_90892_level0_col7" class="col_heading level0 col7" >RF</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_90892_level0_row0" class="row_heading level0 row0" >2</th>
#       <td id="T_90892_row0_col0" class="data row0 col0" >LA2</td>
#       <td id="T_90892_row0_col1" class="data row0 col1" >LB2</td>
#       <td id="T_90892_row0_col2" class="data row0 col2" >LC2</td>
#       <td id="T_90892_row0_col3" class="data row0 col3" >LD2</td>
#       <td id="T_90892_row0_col4" class="data row0 col4" >RC2</td>
#       <td id="T_90892_row0_col5" class="data row0 col5" >RD2</td>
#       <td id="T_90892_row0_col6" class="data row0 col6" >RE2</td>
#       <td id="T_90892_row0_col7" class="data row0 col7" >RF2</td>
#     </tr>
#     <tr>
#       <th id="T_90892_level0_row1" class="row_heading level0 row1" >3</th>
#       <td id="T_90892_row1_col0" class="data row1 col0" >LA3</td>
#       <td id="T_90892_row1_col1" class="data row1 col1" >LB3</td>
#       <td id="T_90892_row1_col2" class="data row1 col2" >LC3</td>
#       <td id="T_90892_row1_col3" class="data row1 col3" >LD3</td>
#       <td id="T_90892_row1_col4" class="data row1 col4" >RC3</td>
#       <td id="T_90892_row1_col5" class="data row1 col5" >RD3</td>
#       <td id="T_90892_row1_col6" class="data row1 col6" >RE3</td>
#       <td id="T_90892_row1_col7" class="data row1 col7" >RF3</td>
#     </tr>
#     <tr>
#       <th id="T_90892_level0_row2" class="row_heading level0 row2" >4</th>
#       <td id="T_90892_row2_col0" class="data row2 col0" >nan</td>
#       <td id="T_90892_row2_col1" class="data row2 col1" >nan</td>
#       <td id="T_90892_row2_col2" class="data row2 col2" >nan</td>
#       <td id="T_90892_row2_col3" class="data row2 col3" >nan</td>
#       <td id="T_90892_row2_col4" class="data row2 col4" >RC4</td>
#       <td id="T_90892_row2_col5" class="data row2 col5" >RD4</td>
#       <td id="T_90892_row2_col6" class="data row2 col6" >RE4</td>
#       <td id="T_90892_row2_col7" class="data row2 col7" >RF4</td>
#     </tr>
#     <tr>
#       <th id="T_90892_level0_row3" class="row_heading level0 row3" >5</th>
#       <td id="T_90892_row3_col0" class="data row3 col0" >nan</td>
#       <td id="T_90892_row3_col1" class="data row3 col1" >nan</td>
#       <td id="T_90892_row3_col2" class="data row3 col2" >nan</td>
#       <td id="T_90892_row3_col3" class="data row3 col3" >nan</td>
#       <td id="T_90892_row3_col4" class="data row3 col4" >RC5</td>
#       <td id="T_90892_row3_col5" class="data row3 col5" >RD5</td>
#       <td id="T_90892_row3_col6" class="data row3 col6" >RE5</td>
#       <td id="T_90892_row3_col7" class="data row3 col7" >RF5</td>
#     </tr>
#   </tbody>
# </table>

# %%
hdisplay([left.join(right, how='inner'),
          left.join(right, how='outer')],
          ["how='inner'","how='outer"]
          )
# Out:
# <style type="text/css">
# #T_8ab78 th {
#   text-align: left;
#   vertical-align: top;
# }
# </style>
# <table id="T_8ab78" style='display:inline; margin-right: 50px;'>
#   <caption>how='inner'</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_8ab78_level0_col0" class="col_heading level0 col0" >LA</th>
#       <th id="T_8ab78_level0_col1" class="col_heading level0 col1" >LB</th>
#       <th id="T_8ab78_level0_col2" class="col_heading level0 col2" >LC</th>
#       <th id="T_8ab78_level0_col3" class="col_heading level0 col3" >LD</th>
#       <th id="T_8ab78_level0_col4" class="col_heading level0 col4" >RC</th>
#       <th id="T_8ab78_level0_col5" class="col_heading level0 col5" >RD</th>
#       <th id="T_8ab78_level0_col6" class="col_heading level0 col6" >RE</th>
#       <th id="T_8ab78_level0_col7" class="col_heading level0 col7" >RF</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_8ab78_level0_row0" class="row_heading level0 row0" >2</th>
#       <td id="T_8ab78_row0_col0" class="data row0 col0" >LA2</td>
#       <td id="T_8ab78_row0_col1" class="data row0 col1" >LB2</td>
#       <td id="T_8ab78_row0_col2" class="data row0 col2" >LC2</td>
#       <td id="T_8ab78_row0_col3" class="data row0 col3" >LD2</td>
#       <td id="T_8ab78_row0_col4" class="data row0 col4" >RC2</td>
#       <td id="T_8ab78_row0_col5" class="data row0 col5" >RD2</td>
#       <td id="T_8ab78_row0_col6" class="data row0 col6" >RE2</td>
#       <td id="T_8ab78_row0_col7" class="data row0 col7" >RF2</td>
#     </tr>
#     <tr>
#       <th id="T_8ab78_level0_row1" class="row_heading level0 row1" >3</th>
#       <td id="T_8ab78_row1_col0" class="data row1 col0" >LA3</td>
#       <td id="T_8ab78_row1_col1" class="data row1 col1" >LB3</td>
#       <td id="T_8ab78_row1_col2" class="data row1 col2" >LC3</td>
#       <td id="T_8ab78_row1_col3" class="data row1 col3" >LD3</td>
#       <td id="T_8ab78_row1_col4" class="data row1 col4" >RC3</td>
#       <td id="T_8ab78_row1_col5" class="data row1 col5" >RD3</td>
#       <td id="T_8ab78_row1_col6" class="data row1 col6" >RE3</td>
#       <td id="T_8ab78_row1_col7" class="data row1 col7" >RF3</td>
#     </tr>
#   </tbody>
# </table>
# <style type="text/css">
# #T_c24b1 th {
#   text-align: left;
#   vertical-align: top;
# }
# </style>
# <table id="T_c24b1" style='display:inline; margin-right: 50px;'>
#   <caption>how='outer</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_c24b1_level0_col0" class="col_heading level0 col0" >LA</th>
#       <th id="T_c24b1_level0_col1" class="col_heading level0 col1" >LB</th>
#       <th id="T_c24b1_level0_col2" class="col_heading level0 col2" >LC</th>
#       <th id="T_c24b1_level0_col3" class="col_heading level0 col3" >LD</th>
#       <th id="T_c24b1_level0_col4" class="col_heading level0 col4" >RC</th>
#       <th id="T_c24b1_level0_col5" class="col_heading level0 col5" >RD</th>
#       <th id="T_c24b1_level0_col6" class="col_heading level0 col6" >RE</th>
#       <th id="T_c24b1_level0_col7" class="col_heading level0 col7" >RF</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_c24b1_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_c24b1_row0_col0" class="data row0 col0" >LA0</td>
#       <td id="T_c24b1_row0_col1" class="data row0 col1" >LB0</td>
#       <td id="T_c24b1_row0_col2" class="data row0 col2" >LC0</td>
#       <td id="T_c24b1_row0_col3" class="data row0 col3" >LD0</td>
#       <td id="T_c24b1_row0_col4" class="data row0 col4" >nan</td>
#       <td id="T_c24b1_row0_col5" class="data row0 col5" >nan</td>
#       <td id="T_c24b1_row0_col6" class="data row0 col6" >nan</td>
#       <td id="T_c24b1_row0_col7" class="data row0 col7" >nan</td>
#     </tr>
#     <tr>
#       <th id="T_c24b1_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_c24b1_row1_col0" class="data row1 col0" >LA1</td>
#       <td id="T_c24b1_row1_col1" class="data row1 col1" >LB1</td>
#       <td id="T_c24b1_row1_col2" class="data row1 col2" >LC1</td>
#       <td id="T_c24b1_row1_col3" class="data row1 col3" >LD1</td>
#       <td id="T_c24b1_row1_col4" class="data row1 col4" >nan</td>
#       <td id="T_c24b1_row1_col5" class="data row1 col5" >nan</td>
#       <td id="T_c24b1_row1_col6" class="data row1 col6" >nan</td>
#       <td id="T_c24b1_row1_col7" class="data row1 col7" >nan</td>
#     </tr>
#     <tr>
#       <th id="T_c24b1_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_c24b1_row2_col0" class="data row2 col0" >LA2</td>
#       <td id="T_c24b1_row2_col1" class="data row2 col1" >LB2</td>
#       <td id="T_c24b1_row2_col2" class="data row2 col2" >LC2</td>
#       <td id="T_c24b1_row2_col3" class="data row2 col3" >LD2</td>
#       <td id="T_c24b1_row2_col4" class="data row2 col4" >RC2</td>
#       <td id="T_c24b1_row2_col5" class="data row2 col5" >RD2</td>
#       <td id="T_c24b1_row2_col6" class="data row2 col6" >RE2</td>
#       <td id="T_c24b1_row2_col7" class="data row2 col7" >RF2</td>
#     </tr>
#     <tr>
#       <th id="T_c24b1_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_c24b1_row3_col0" class="data row3 col0" >LA3</td>
#       <td id="T_c24b1_row3_col1" class="data row3 col1" >LB3</td>
#       <td id="T_c24b1_row3_col2" class="data row3 col2" >LC3</td>
#       <td id="T_c24b1_row3_col3" class="data row3 col3" >LD3</td>
#       <td id="T_c24b1_row3_col4" class="data row3 col4" >RC3</td>
#       <td id="T_c24b1_row3_col5" class="data row3 col5" >RD3</td>
#       <td id="T_c24b1_row3_col6" class="data row3 col6" >RE3</td>
#       <td id="T_c24b1_row3_col7" class="data row3 col7" >RF3</td>
#     </tr>
#     <tr>
#       <th id="T_c24b1_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_c24b1_row4_col0" class="data row4 col0" >nan</td>
#       <td id="T_c24b1_row4_col1" class="data row4 col1" >nan</td>
#       <td id="T_c24b1_row4_col2" class="data row4 col2" >nan</td>
#       <td id="T_c24b1_row4_col3" class="data row4 col3" >nan</td>
#       <td id="T_c24b1_row4_col4" class="data row4 col4" >RC4</td>
#       <td id="T_c24b1_row4_col5" class="data row4 col5" >RD4</td>
#       <td id="T_c24b1_row4_col6" class="data row4 col6" >RE4</td>
#       <td id="T_c24b1_row4_col7" class="data row4 col7" >RF4</td>
#     </tr>
#     <tr>
#       <th id="T_c24b1_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_c24b1_row5_col0" class="data row5 col0" >nan</td>
#       <td id="T_c24b1_row5_col1" class="data row5 col1" >nan</td>
#       <td id="T_c24b1_row5_col2" class="data row5 col2" >nan</td>
#       <td id="T_c24b1_row5_col3" class="data row5 col3" >nan</td>
#       <td id="T_c24b1_row5_col4" class="data row5 col4" >RC5</td>
#       <td id="T_c24b1_row5_col5" class="data row5 col5" >RD5</td>
#       <td id="T_c24b1_row5_col6" class="data row5 col6" >RE5</td>
#       <td id="T_c24b1_row5_col7" class="data row5 col7" >RF5</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ## Merge
# - Pandas .merge() method is similar to join but is more versatile, and allows us to specify columns beside the index to join on for both dataframes.
# - Merge kombinerar ihop datan så att **datan** matchar (join matchar på rader)
# - Note: how parameter works the same as for join()m but the default for merge() is "inner", not "left".
# - Parameters:
#     - on='col', ange på vilken col man ska merga
#     - left_on='col i left df', right_on='col i right df', gör så man kan joina ihop fastän kolumnerna inte heter samma sak.

# %%
# Sample data:

left = sample_df("A0","E3")
left.loc[:,"F"] = ["F10","F11","F12","F13"]
right = sample_df("F10","J13")
hdisplay([left, right],['Left','Right'])
# Out:
# <style type="text/css">
# #T_3c9dc th {
#   text-align: left;
#   vertical-align: top;
# }
# </style>
# <table id="T_3c9dc" style='display:inline; margin-right: 50px;'>
#   <caption>Left</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_3c9dc_level0_col0" class="col_heading level0 col0" >A</th>
#       <th id="T_3c9dc_level0_col1" class="col_heading level0 col1" >B</th>
#       <th id="T_3c9dc_level0_col2" class="col_heading level0 col2" >C</th>
#       <th id="T_3c9dc_level0_col3" class="col_heading level0 col3" >D</th>
#       <th id="T_3c9dc_level0_col4" class="col_heading level0 col4" >E</th>
#       <th id="T_3c9dc_level0_col5" class="col_heading level0 col5" >F</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_3c9dc_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_3c9dc_row0_col0" class="data row0 col0" >A0</td>
#       <td id="T_3c9dc_row0_col1" class="data row0 col1" >B0</td>
#       <td id="T_3c9dc_row0_col2" class="data row0 col2" >C0</td>
#       <td id="T_3c9dc_row0_col3" class="data row0 col3" >D0</td>
#       <td id="T_3c9dc_row0_col4" class="data row0 col4" >E0</td>
#       <td id="T_3c9dc_row0_col5" class="data row0 col5" >F10</td>
#     </tr>
#     <tr>
#       <th id="T_3c9dc_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_3c9dc_row1_col0" class="data row1 col0" >A1</td>
#       <td id="T_3c9dc_row1_col1" class="data row1 col1" >B1</td>
#       <td id="T_3c9dc_row1_col2" class="data row1 col2" >C1</td>
#       <td id="T_3c9dc_row1_col3" class="data row1 col3" >D1</td>
#       <td id="T_3c9dc_row1_col4" class="data row1 col4" >E1</td>
#       <td id="T_3c9dc_row1_col5" class="data row1 col5" >F11</td>
#     </tr>
#     <tr>
#       <th id="T_3c9dc_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_3c9dc_row2_col0" class="data row2 col0" >A2</td>
#       <td id="T_3c9dc_row2_col1" class="data row2 col1" >B2</td>
#       <td id="T_3c9dc_row2_col2" class="data row2 col2" >C2</td>
#       <td id="T_3c9dc_row2_col3" class="data row2 col3" >D2</td>
#       <td id="T_3c9dc_row2_col4" class="data row2 col4" >E2</td>
#       <td id="T_3c9dc_row2_col5" class="data row2 col5" >F12</td>
#     </tr>
#     <tr>
#       <th id="T_3c9dc_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_3c9dc_row3_col0" class="data row3 col0" >A3</td>
#       <td id="T_3c9dc_row3_col1" class="data row3 col1" >B3</td>
#       <td id="T_3c9dc_row3_col2" class="data row3 col2" >C3</td>
#       <td id="T_3c9dc_row3_col3" class="data row3 col3" >D3</td>
#       <td id="T_3c9dc_row3_col4" class="data row3 col4" >E3</td>
#       <td id="T_3c9dc_row3_col5" class="data row3 col5" >F13</td>
#     </tr>
#   </tbody>
# </table>
# <style type="text/css">
# #T_b351e th {
#   text-align: left;
#   vertical-align: top;
# }
# </style>
# <table id="T_b351e" style='display:inline; margin-right: 50px;'>
#   <caption>Right</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_b351e_level0_col0" class="col_heading level0 col0" >F</th>
#       <th id="T_b351e_level0_col1" class="col_heading level0 col1" >G</th>
#       <th id="T_b351e_level0_col2" class="col_heading level0 col2" >H</th>
#       <th id="T_b351e_level0_col3" class="col_heading level0 col3" >I</th>
#       <th id="T_b351e_level0_col4" class="col_heading level0 col4" >J</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_b351e_level0_row0" class="row_heading level0 row0" >10</th>
#       <td id="T_b351e_row0_col0" class="data row0 col0" >F10</td>
#       <td id="T_b351e_row0_col1" class="data row0 col1" >G10</td>
#       <td id="T_b351e_row0_col2" class="data row0 col2" >H10</td>
#       <td id="T_b351e_row0_col3" class="data row0 col3" >I10</td>
#       <td id="T_b351e_row0_col4" class="data row0 col4" >J10</td>
#     </tr>
#     <tr>
#       <th id="T_b351e_level0_row1" class="row_heading level0 row1" >11</th>
#       <td id="T_b351e_row1_col0" class="data row1 col0" >F11</td>
#       <td id="T_b351e_row1_col1" class="data row1 col1" >G11</td>
#       <td id="T_b351e_row1_col2" class="data row1 col2" >H11</td>
#       <td id="T_b351e_row1_col3" class="data row1 col3" >I11</td>
#       <td id="T_b351e_row1_col4" class="data row1 col4" >J11</td>
#     </tr>
#     <tr>
#       <th id="T_b351e_level0_row2" class="row_heading level0 row2" >12</th>
#       <td id="T_b351e_row2_col0" class="data row2 col0" >F12</td>
#       <td id="T_b351e_row2_col1" class="data row2 col1" >G12</td>
#       <td id="T_b351e_row2_col2" class="data row2 col2" >H12</td>
#       <td id="T_b351e_row2_col3" class="data row2 col3" >I12</td>
#       <td id="T_b351e_row2_col4" class="data row2 col4" >J12</td>
#     </tr>
#     <tr>
#       <th id="T_b351e_level0_row3" class="row_heading level0 row3" >13</th>
#       <td id="T_b351e_row3_col0" class="data row3 col0" >F13</td>
#       <td id="T_b351e_row3_col1" class="data row3 col1" >G13</td>
#       <td id="T_b351e_row3_col2" class="data row3 col2" >H13</td>
#       <td id="T_b351e_row3_col3" class="data row3 col3" >I13</td>
#       <td id="T_b351e_row3_col4" class="data row3 col4" >J13</td>
#     </tr>
#   </tbody>
# </table>

# %%
left.merge(right)
# Out:
#     A   B   C   D   E    F    G    H    I    J
# 0  A0  B0  C0  D0  E0  F10  G10  H10  I10  J10
# 1  A1  B1  C1  D1  E1  F11  G11  H11  I11  J11
# 2  A2  B2  C2  D2  E2  F12  G12  H12  I12  J12
# 3  A3  B3  C3  D3  E3  F13  G13  H13  I13  J13

# %% [markdown]
# ## Working with real data

# %%
employees = pd.read_json("../Data/employees.json")
display(employees)
departments = pd.read_json("../Data/departments.json")
display(departments)
# Out:
#   first_name last_name              job_title  salary       department
# 0       John       Doe         Sales Director  120000            Sales
# 1       Jane     Smith         HR Coordinator   60000  Human Resources
# 2    Michael   Johnson      Software Engineer  110000               IT
# 3      Sarah  Williams   Marketing Specialist   75000            Sales
# 4      David     Brown             HR Manager   90000  Human Resources
# 5      Emily     Davis  IT Support Specialist   55000               IT
# 6      Jacob    Wilson   Sales Representative   80000            Sales
# 7     Olivia     Moore      Marketing Manager  100000            Sales
# 8      Ethan       Lee      Financial Analyst   85000            Sales
# 9     Sophia    Taylor           HR Assistant   50000  Human Resources
#    department_name  department_head       location  office_number   budget
# 0            Sales   Sarah Williams       New York            101  1000000
# 1  Human Resources      David Brown        Chicago            202   800000
# 2               IT  Michael Johnson  San Francisco            303  1200000

# %%
# mergar ihop
employees.merge(departments, left_on='department', right_on='department_name')
# Out:
#   first_name last_name              job_title  salary       department  \
# 0       John       Doe         Sales Director  120000            Sales
# 1      Sarah  Williams   Marketing Specialist   75000            Sales
# 2      Jacob    Wilson   Sales Representative   80000            Sales
# 3     Olivia     Moore      Marketing Manager  100000            Sales
# 4      Ethan       Lee      Financial Analyst   85000            Sales
# 5       Jane     Smith         HR Coordinator   60000  Human Resources
# 6      David     Brown             HR Manager   90000  Human Resources
# 7     Sophia    Taylor           HR Assistant   50000  Human Resources
# 8    Michael   Johnson      Software Engineer  110000               IT
# 9      Emily     Davis  IT Support Specialist   55000               IT
#
#    department_name  department_head       location  office_number   budget
# 0            Sales   Sarah Williams       New York            101  1000000
# 1            Sales   Sarah Williams       New York            101  1000000
# 2            Sales   Sarah Williams       New York            101  1000000
# 3            Sales   Sarah Williams       New York            101  1000000
# 4            Sales   Sarah Williams       New York            101  1000000
# 5  Human Resources      David Brown        Chicago            202   800000
# 6  Human Resources      David Brown        Chicago            202   800000
# 7  Human Resources      David Brown        Chicago            202   800000
# 8               IT  Michael Johnson  San Francisco            303  1200000
# 9               IT  Michael Johnson  San Francisco            303  1200000

# %%
nowrap_display(employees.merge(departments, left_on='department', right_on='department_name'))
# Out:
# <style type="text/css">
# #T_a3941 th {
#   text-align: left;
# }
# #T_a3941_row0_col0, #T_a3941_row0_col1, #T_a3941_row0_col2, #T_a3941_row0_col3, #T_a3941_row0_col4, #T_a3941_row0_col5, #T_a3941_row0_col6, #T_a3941_row0_col7, #T_a3941_row0_col8, #T_a3941_row0_col9, #T_a3941_row1_col0, #T_a3941_row1_col1, #T_a3941_row1_col2, #T_a3941_row1_col3, #T_a3941_row1_col4, #T_a3941_row1_col5, #T_a3941_row1_col6, #T_a3941_row1_col7, #T_a3941_row1_col8, #T_a3941_row1_col9, #T_a3941_row2_col0, #T_a3941_row2_col1, #T_a3941_row2_col2, #T_a3941_row2_col3, #T_a3941_row2_col4, #T_a3941_row2_col5, #T_a3941_row2_col6, #T_a3941_row2_col7, #T_a3941_row2_col8, #T_a3941_row2_col9, #T_a3941_row3_col0, #T_a3941_row3_col1, #T_a3941_row3_col2, #T_a3941_row3_col3, #T_a3941_row3_col4, #T_a3941_row3_col5, #T_a3941_row3_col6, #T_a3941_row3_col7, #T_a3941_row3_col8, #T_a3941_row3_col9, #T_a3941_row4_col0, #T_a3941_row4_col1, #T_a3941_row4_col2, #T_a3941_row4_col3, #T_a3941_row4_col4, #T_a3941_row4_col5, #T_a3941_row4_col6, #T_a3941_row4_col7, #T_a3941_row4_col8, #T_a3941_row4_col9, #T_a3941_row5_col0, #T_a3941_row5_col1, #T_a3941_row5_col2, #T_a3941_row5_col3, #T_a3941_row5_col4, #T_a3941_row5_col5, #T_a3941_row5_col6, #T_a3941_row5_col7, #T_a3941_row5_col8, #T_a3941_row5_col9, #T_a3941_row6_col0, #T_a3941_row6_col1, #T_a3941_row6_col2, #T_a3941_row6_col3, #T_a3941_row6_col4, #T_a3941_row6_col5, #T_a3941_row6_col6, #T_a3941_row6_col7, #T_a3941_row6_col8, #T_a3941_row6_col9, #T_a3941_row7_col0, #T_a3941_row7_col1, #T_a3941_row7_col2, #T_a3941_row7_col3, #T_a3941_row7_col4, #T_a3941_row7_col5, #T_a3941_row7_col6, #T_a3941_row7_col7, #T_a3941_row7_col8, #T_a3941_row7_col9, #T_a3941_row8_col0, #T_a3941_row8_col1, #T_a3941_row8_col2, #T_a3941_row8_col3, #T_a3941_row8_col4, #T_a3941_row8_col5, #T_a3941_row8_col6, #T_a3941_row8_col7, #T_a3941_row8_col8, #T_a3941_row8_col9, #T_a3941_row9_col0, #T_a3941_row9_col1, #T_a3941_row9_col2, #T_a3941_row9_col3, #T_a3941_row9_col4, #T_a3941_row9_col5, #T_a3941_row9_col6, #T_a3941_row9_col7, #T_a3941_row9_col8, #T_a3941_row9_col9 {
#   font-size: 12pt;
#   text-align: left;
#   white-space: nowrap;
# }
# </style>
# <table id="T_a3941">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_a3941_level0_col0" class="col_heading level0 col0" >first_name</th>
#       <th id="T_a3941_level0_col1" class="col_heading level0 col1" >last_name</th>
#       <th id="T_a3941_level0_col2" class="col_heading level0 col2" >job_title</th>
#       <th id="T_a3941_level0_col3" class="col_heading level0 col3" >salary</th>
#       <th id="T_a3941_level0_col4" class="col_heading level0 col4" >department</th>
#       <th id="T_a3941_level0_col5" class="col_heading level0 col5" >department_name</th>
#       <th id="T_a3941_level0_col6" class="col_heading level0 col6" >department_head</th>
#       <th id="T_a3941_level0_col7" class="col_heading level0 col7" >location</th>
#       <th id="T_a3941_level0_col8" class="col_heading level0 col8" >office_number</th>
#       <th id="T_a3941_level0_col9" class="col_heading level0 col9" >budget</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_a3941_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_a3941_row0_col0" class="data row0 col0" >John</td>
#       <td id="T_a3941_row0_col1" class="data row0 col1" >Doe</td>
#       <td id="T_a3941_row0_col2" class="data row0 col2" >Sales Director</td>
#       <td id="T_a3941_row0_col3" class="data row0 col3" >120000</td>
#       <td id="T_a3941_row0_col4" class="data row0 col4" >Sales</td>
#       <td id="T_a3941_row0_col5" class="data row0 col5" >Sales</td>
#       <td id="T_a3941_row0_col6" class="data row0 col6" >Sarah Williams</td>
#       <td id="T_a3941_row0_col7" class="data row0 col7" >New York</td>
#       <td id="T_a3941_row0_col8" class="data row0 col8" >101</td>
#       <td id="T_a3941_row0_col9" class="data row0 col9" >1000000</td>
#     </tr>
#     <tr>
#       <th id="T_a3941_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_a3941_row1_col0" class="data row1 col0" >Sarah</td>
#       <td id="T_a3941_row1_col1" class="data row1 col1" >Williams</td>
#       <td id="T_a3941_row1_col2" class="data row1 col2" >Marketing Specialist</td>
#       <td id="T_a3941_row1_col3" class="data row1 col3" >75000</td>
#       <td id="T_a3941_row1_col4" class="data row1 col4" >Sales</td>
#       <td id="T_a3941_row1_col5" class="data row1 col5" >Sales</td>
#       <td id="T_a3941_row1_col6" class="data row1 col6" >Sarah Williams</td>
#       <td id="T_a3941_row1_col7" class="data row1 col7" >New York</td>
#       <td id="T_a3941_row1_col8" class="data row1 col8" >101</td>
#       <td id="T_a3941_row1_col9" class="data row1 col9" >1000000</td>
#     </tr>
#     <tr>
#       <th id="T_a3941_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_a3941_row2_col0" class="data row2 col0" >Jacob</td>
#       <td id="T_a3941_row2_col1" class="data row2 col1" >Wilson</td>
#       <td id="T_a3941_row2_col2" class="data row2 col2" >Sales Representative</td>
#       <td id="T_a3941_row2_col3" class="data row2 col3" >80000</td>
#       <td id="T_a3941_row2_col4" class="data row2 col4" >Sales</td>
#       <td id="T_a3941_row2_col5" class="data row2 col5" >Sales</td>
#       <td id="T_a3941_row2_col6" class="data row2 col6" >Sarah Williams</td>
#       <td id="T_a3941_row2_col7" class="data row2 col7" >New York</td>
#       <td id="T_a3941_row2_col8" class="data row2 col8" >101</td>
#       <td id="T_a3941_row2_col9" class="data row2 col9" >1000000</td>
#     </tr>
#     <tr>
#       <th id="T_a3941_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_a3941_row3_col0" class="data row3 col0" >Olivia</td>
#       <td id="T_a3941_row3_col1" class="data row3 col1" >Moore</td>
#       <td id="T_a3941_row3_col2" class="data row3 col2" >Marketing Manager</td>
#       <td id="T_a3941_row3_col3" class="data row3 col3" >100000</td>
#       <td id="T_a3941_row3_col4" class="data row3 col4" >Sales</td>
#       <td id="T_a3941_row3_col5" class="data row3 col5" >Sales</td>
#       <td id="T_a3941_row3_col6" class="data row3 col6" >Sarah Williams</td>
#       <td id="T_a3941_row3_col7" class="data row3 col7" >New York</td>
#       <td id="T_a3941_row3_col8" class="data row3 col8" >101</td>
#       <td id="T_a3941_row3_col9" class="data row3 col9" >1000000</td>
#     </tr>
#     <tr>
#       <th id="T_a3941_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_a3941_row4_col0" class="data row4 col0" >Ethan</td>
#       <td id="T_a3941_row4_col1" class="data row4 col1" >Lee</td>
#       <td id="T_a3941_row4_col2" class="data row4 col2" >Financial Analyst</td>
#       <td id="T_a3941_row4_col3" class="data row4 col3" >85000</td>
#       <td id="T_a3941_row4_col4" class="data row4 col4" >Sales</td>
#       <td id="T_a3941_row4_col5" class="data row4 col5" >Sales</td>
#       <td id="T_a3941_row4_col6" class="data row4 col6" >Sarah Williams</td>
#       <td id="T_a3941_row4_col7" class="data row4 col7" >New York</td>
#       <td id="T_a3941_row4_col8" class="data row4 col8" >101</td>
#       <td id="T_a3941_row4_col9" class="data row4 col9" >1000000</td>
#     </tr>
#     <tr>
#       <th id="T_a3941_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_a3941_row5_col0" class="data row5 col0" >Jane</td>
#       <td id="T_a3941_row5_col1" class="data row5 col1" >Smith</td>
#       <td id="T_a3941_row5_col2" class="data row5 col2" >HR Coordinator</td>
#       <td id="T_a3941_row5_col3" class="data row5 col3" >60000</td>
#       <td id="T_a3941_row5_col4" class="data row5 col4" >Human Resources</td>
#       <td id="T_a3941_row5_col5" class="data row5 col5" >Human Resources</td>
#       <td id="T_a3941_row5_col6" class="data row5 col6" >David Brown</td>
#       <td id="T_a3941_row5_col7" class="data row5 col7" >Chicago</td>
#       <td id="T_a3941_row5_col8" class="data row5 col8" >202</td>
#       <td id="T_a3941_row5_col9" class="data row5 col9" >800000</td>
#     </tr>
#     <tr>
#       <th id="T_a3941_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_a3941_

# %%
# använder denna 'new_df' längre ner
new_df = employees.merge(departments, left_on='department', right_on='department_name')
new_df.drop(columns='department_name', inplace=True)
new_df
# Out:
#   first_name last_name              job_title  salary       department  \
# 0       John       Doe         Sales Director  120000            Sales
# 1      Sarah  Williams   Marketing Specialist   75000            Sales
# 2      Jacob    Wilson   Sales Representative   80000            Sales
# 3     Olivia     Moore      Marketing Manager  100000            Sales
# 4      Ethan       Lee      Financial Analyst   85000            Sales
# 5       Jane     Smith         HR Coordinator   60000  Human Resources
# 6      David     Brown             HR Manager   90000  Human Resources
# 7     Sophia    Taylor           HR Assistant   50000  Human Resources
# 8    Michael   Johnson      Software Engineer  110000               IT
# 9      Emily     Davis  IT Support Specialist   55000               IT
#
#    department_head       location  office_number   budget
# 0   Sarah Williams       New York            101  1000000
# 1   Sarah Williams       New York            101  1000000
# 2   Sarah Williams       New York            101  1000000
# 3   Sarah Williams       New York            101  1000000
# 4   Sarah Williams       New York            101  1000000
# 5      David Brown        Chicago            202   800000
# 6      David Brown        Chicago            202   800000
# 7      David Brown        Chicago            202   800000
# 8  Michael Johnson  San Francisco            303  1200000
# 9  Michael Johnson  San Francisco            303  1200000

# %% [markdown]
# Mini challenge: Joina ihop nedan tabeller.

# %%
users = pd.read_json("../Data/users.json")
display(users)
employees = pd.read_json("../Data/employees.json")
display(employees)
# Out:
#   username                                           password  \
# 0   johdoe  7e684c07e48bf68c0181306c2dab1a0e2b8298e9a59a37...
# 1   jansmi  a6ab128c25d59951f9eb29a0b63806a0a2df924a384f61...
# 2   micjoh  9f01f5cfa05a6b14367d4d0e6c788c5977f094ad4e2381...
# 3   sarwil  fdb1e5c757d39e5f27065f12f27fbc94d50f47a66e8cdd...
# 4   davbro  1d99b7d777fb1b04ac1bea3d4b04a4ea5f654f9b304da4...
# 5   emidav  1953b5a2e8cc313b6db9f1708e9d0b84a84c6b3a60706e...
# 6   jacwil  8d5ee4f5e3a5e9202a2f21d3b7c30a10c9c51d0133a731...
# 7   olimoo  79cfd142536a5d27528d3306ef28e26d038c625764167b...
# 8   ethlee  5f51c17c9b81d68a1c9b99f1a8627a457bd0a4048d594c...
# 9   soptay  a429b013ebfb9f86a3cb8cf2311e2bfa3b00b238d439eb...
#
#                              email           phone         host
# 0         john.doe@mockcompany.com  (212) 591-7254  192.168.1.1
# 1       jane.smith@mockcompany.com  (312) 623-3364  192.168.1.2
# 2  michael.johnson@mockcompany.com  (415) 602-6872  192.168.1.3
# 3   sarah.williams@mockcompany.com  (212) 623-6568  192.168.1.1
# 4      david.brown@mockcompany.com  (312) 709-8933  192.168.1.2
# 5      emily.davis@mockcompany.com  (415) 775-6149  192.168.1.3
# 6     jacob.wilson@mockcompany.com  (212) 285-2027  192.168.1.1
# 7     olivia.moore@mockcompany.com  (212) 335-5297  192.168.1.1
# 8        ethan.lee@mockcompany.com  (212) 509-8922  192.168.1.1
# 9    sophia.taylor@mockcompany.com  (312) 826-6711  192.168.1.2
#   first_name last_name              job_title  salary       department
# 0       John       Doe         Sales Director  120000            Sales
# 1       Jane     Smith         HR Coordinator   60000  Human Resources
# 2    Michael   Johnson      Software Engineer  110000               IT
# 3      Sarah  Williams   Marketing Specialist   75000            Sales
# 4      David     Brown             HR Manager   90000  Human Resources
# 5      Emily     Davis  IT Support Specialist   55000               IT
# 6      Jacob    Wilson   Sales Representative   80000            Sales
# 7     Olivia     Moore      Marketing Manager  100000            Sales
# 8      Ethan       Lee      Financial Analyst   85000            Sales
# 9     Sophia    Taylor           HR Assistant   50000  Human Resources

# %%
# Mitt försök. Fungerar, men det finns kanske bättre sätt?
# Feedback från läraren: man ska helst inte använda for loopar på DataFrames, det finns andra sätt.
first3_list=[]
last3_list=[]
final_list=[]

for name in employees['first_name']:
    first3_list.append(name[0:3].lower())

for name in employees['last_name']:
    last3_list.append(name[0:3].lower())

for index in range(len(first3_list)):
    final_list.append(first3_list[index]+last3_list[index])

final_list

employees['username'] = final_list
employees

employees.merge(users, on='username')
# Out:
#   first_name last_name              job_title  salary       department  \
# 0       John       Doe         Sales Director  120000            Sales
# 1       Jane     Smith         HR Coordinator   60000  Human Resources
# 2    Michael   Johnson      Software Engineer  110000               IT
# 3      Sarah  Williams   Marketing Specialist   75000            Sales
# 4      David     Brown             HR Manager   90000  Human Resources
# 5      Emily     Davis  IT Support Specialist   55000               IT
# 6      Jacob    Wilson   Sales Representative   80000            Sales
# 7     Olivia     Moore      Marketing Manager  100000            Sales
# 8      Ethan       Lee      Financial Analyst   85000            Sales
# 9     Sophia    Taylor           HR Assistant   50000  Human Resources
#
#   username                                           password  \
# 0   johdoe  7e684c07e48bf68c0181306c2dab1a0e2b8298e9a59a37...
# 1   jansmi  a6ab128c25d59951f9eb29a0b63806a0a2df924a384f61...
# 2   micjoh  9f01f5cfa05a6b14367d4d0e6c788c5977f094ad4e2381...
# 3   sarwil  fdb1e5c757d39e5f27065f12f27fbc94d50f47a66e8cdd...
# 4   davbro  1d99b7d777fb1b04ac1bea3d4b04a4ea5f654f9b304da4...
# 5   emidav  1953b5a2e8cc313b6db9f1708e9d0b84a84c6b3a60706e...
# 6   jacwil  8d5ee4f5e3a5e9202a2f21d3b7c30a10c9c51d0133a731...
# 7   olimoo  79cfd142536a5d27528d3306ef28e26d038c625764167b...
# 8   ethlee  5f51c17c9b81d68a1c9b99f1a8627a457bd0a4048d594c...
# 9   soptay  a429b013ebfb9f86a3cb8cf2311e2bfa3b00b238d439eb...
#
#                              email           phone         host
# 0         john.doe@mockcompany.com  (212) 591-7254  192.168.1.1
# 1       jane.smith@mockcompany.com  (312) 623-3364  192.168.1.2
# 2  michael.johnson@mockcompany.com  (415) 602-6872  192.168.1.3
# 3   sarah.williams@mockcompany.com  (212) 623-6568  192.168.1.1
# 4      david.brown@mockcompany.com  (312) 709-8933  192.168.1.2
# 5      emily.davis@mockcompany.com  (415) 775-6149  192.168.1.3
# 6     jacob.wilson@mockcompany.com  (212) 285-2027  192.168.1.1
# 7     olivia.moore@mockcompany.com  (212) 335-5297  192.168.1.1
# 8        ethan.lee@mockcompany.com  (212) 509-8922  192.168.1.1
# 9    sophia.taylor@mockcompany.com  (312) 826-6711  192.168.1.2

# %% [markdown]
# ##### Lärarens version
# ###### Lektion 4
# - apply(), gör samma sak på alla element i en Serie
# - map(), gör samma sak på alla element i en DataFrame
# - lambda funktionen gör på varje rad i en DF eller serie
# - .insert() metoden, för att inserta en kolumn på en specifik plats i en DF

# %%
# Läser in datan igen
users = pd.read_json("../Data/users.json")
display(users)
employees = pd.read_json("../Data/employees.json")
display(employees)
# Out:
#   username                                           password  \
# 0   johdoe  7e684c07e48bf68c0181306c2dab1a0e2b8298e9a59a37...
# 1   jansmi  a6ab128c25d59951f9eb29a0b63806a0a2df924a384f61...
# 2   micjoh  9f01f5cfa05a6b14367d4d0e6c788c5977f094ad4e2381...
# 3   sarwil  fdb1e5c757d39e5f27065f12f27fbc94d50f47a66e8cdd...
# 4   davbro  1d99b7d777fb1b04ac1bea3d4b04a4ea5f654f9b304da4...
# 5   emidav  1953b5a2e8cc313b6db9f1708e9d0b84a84c6b3a60706e...
# 6   jacwil  8d5ee4f5e3a5e9202a2f21d3b7c30a10c9c51d0133a731...
# 7   olimoo  79cfd142536a5d27528d3306ef28e26d038c625764167b...
# 8   ethlee  5f51c17c9b81d68a1c9b99f1a8627a457bd0a4048d594c...
# 9   soptay  a429b013ebfb9f86a3cb8cf2311e2bfa3b00b238d439eb...
#
#                              email           phone         host
# 0         john.doe@mockcompany.com  (212) 591-7254  192.168.1.1
# 1       jane.smith@mockcompany.com  (312) 623-3364  192.168.1.2
# 2  michael.johnson@mockcompany.com  (415) 602-6872  192.168.1.3
# 3   sarah.williams@mockcompany.com  (212) 623-6568  192.168.1.1
# 4      david.brown@mockcompany.com  (312) 709-8933  192.168.1.2
# 5      emily.davis@mockcompany.com  (415) 775-6149  192.168.1.3
# 6     jacob.wilson@mockcompany.com  (212) 285-2027  192.168.1.1
# 7     olivia.moore@mockcompany.com  (212) 335-5297  192.168.1.1
# 8        ethan.lee@mockcompany.com  (212) 509-8922  192.168.1.1
# 9    sophia.taylor@mockcompany.com  (312) 826-6711  192.168.1.2
#   first_name last_name              job_title  salary       department
# 0       John       Doe         Sales Director  120000            Sales
# 1       Jane     Smith         HR Coordinator   60000  Human Resources
# 2    Michael   Johnson      Software Engineer  110000               IT
# 3      Sarah  Williams   Marketing Specialist   75000            Sales
# 4      David     Brown             HR Manager   90000  Human Resources
# 5      Emily     Davis  IT Support Specialist   55000               IT
# 6      Jacob    Wilson   Sales Representative   80000            Sales
# 7     Olivia     Moore      Marketing Manager  100000            Sales
# 8      Ethan       Lee      Financial Analyst   85000            Sales
# 9     Sophia    Taylor           HR Assistant   50000  Human Resources

# %% [markdown]
# ### Nedan är intressant:
# - **lambda funktion** i Pandas för att göra samma sak på flera rader i en DataFrame
# - **insert funktion** för att inserta en Serie på bestämd plats i en DataFrame
# - **apply funktion** för att 'applya' en funktion, i detta fallet på den kolumn som man anger (typ).

# %%
# skapar den behövda kolumnen "username"
employees.insert(0,
                 "username",
                 employees['first_name'].apply(lambda name: name[0:3].lower()) + employees['last_name'].apply(lambda name: name[0:3].lower())
)

display(employees)
# Out:
#   username first_name last_name              job_title  salary  \
# 0   johdoe       John       Doe         Sales Director  120000
# 1   jansmi       Jane     Smith         HR Coordinator   60000
# 2   micjoh    Michael   Johnson      Software Engineer  110000
# 3   sarwil      Sarah  Williams   Marketing Specialist   75000
# 4   davbro      David     Brown             HR Manager   90000
# 5   emidav      Emily     Davis  IT Support Specialist   55000
# 6   jacwil      Jacob    Wilson   Sales Representative   80000
# 7   olimoo     Olivia     Moore      Marketing Manager  100000
# 8   ethlee      Ethan       Lee      Financial Analyst   85000
# 9   soptay     Sophia    Taylor           HR Assistant   50000
#
#         department
# 0            Sales
# 1  Human Resources
# 2               IT
# 3            Sales
# 4  Human Resources
# 5               IT
# 6            Sales
# 7            Sales
# 8            Sales
# 9  Human Resources

# %%
# mergar de två DF'arna
employees.merge(users, on='username')
# Out:
#   username first_name last_name              job_title  salary  \
# 0   johdoe       John       Doe         Sales Director  120000
# 1   jansmi       Jane     Smith         HR Coordinator   60000
# 2   micjoh    Michael   Johnson      Software Engineer  110000
# 3   sarwil      Sarah  Williams   Marketing Specialist   75000
# 4   davbro      David     Brown             HR Manager   90000
# 5   emidav      Emily     Davis  IT Support Specialist   55000
# 6   jacwil      Jacob    Wilson   Sales Representative   80000
# 7   olimoo     Olivia     Moore      Marketing Manager  100000
# 8   ethlee      Ethan       Lee      Financial Analyst   85000
# 9   soptay     Sophia    Taylor           HR Assistant   50000
#
#         department                                           password  \
# 0            Sales  7e684c07e48bf68c0181306c2dab1a0e2b8298e9a59a37...
# 1  Human Resources  a6ab128c25d59951f9eb29a0b63806a0a2df924a384f61...
# 2               IT  9f01f5cfa05a6b14367d4d0e6c788c5977f094ad4e2381...
# 3            Sales  fdb1e5c757d39e5f27065f12f27fbc94d50f47a66e8cdd...
# 4  Human Resources  1d99b7d777fb1b04ac1bea3d4b04a4ea5f654f9b304da4...
# 5               IT  1953b5a2e8cc313b6db9f1708e9d0b84a84c6b3a60706e...
# 6            Sales  8d5ee4f5e3a5e9202a2f21d3b7c30a10c9c51d0133a731...
# 7            Sales  79cfd142536a5d27528d3306ef28e26d038c625764167b...
# 8            Sales  5f51c17c9b81d68a1c9b99f1a8627a457bd0a4048d594c...
# 9  Human Resources  a429b013ebfb9f86a3cb8cf2311e2bfa3b00b238d439eb...
#
#                              email           phone         host
# 0         john.doe@mockcompany.com  (212) 591-7254  192.168.1.1
# 1       jane.smith@mockcompany.com  (312) 623-3364  192.168.1.2
# 2  michael.johnson@mockcompany.com  (415) 602-6872  192.168.1.3
# 3   sarah.williams@mockcompany.com  (212) 623-6568  192.168.1.1
# 4      david.brown@mockcompany.com  (312) 709-8933  192.168.1.2
# 5      emily.davis@mockcompany.com  (415) 775-6149  192.168.1.3
# 6     jacob.wilson@mockcompany.com  (212) 285-2027  192.168.1.1
# 7     olivia.moore@mockcompany.com  (212) 335-5297  192.168.1.1
# 8        ethan.lee@mockcompany.com  (212) 509-8922  192.168.1.1
# 9    sophia.taylor@mockcompany.com  (312) 826-6711  192.168.1.2

# %% [markdown]
# ##### Ett annat sätt som Rasmus i klassen kom på
# - Pandas DataFrame **str funktion**
# - str() funktionen kan användas på strängar i en DF. När man använder den, så sker det på varje rad i DF'en.
# - Om man inte använder 'str' så blir indexeringen på DF istället, dvs i detta fallet tar den de tre första raderna i DF'en, istället för det tre första bokstäverna i strängen.

# %%
# Läser in datan igen
users = pd.read_json("../Data/users.json")
#display(users)
employees = pd.read_json("../Data/employees.json")
#display(employees)

# %%
employees['username'] = (employees['first_name'].str[:3] + employees['last_name'].str[:3]).str.lower()
employees
# Out:
#   first_name last_name              job_title  salary       department  \
# 0       John       Doe         Sales Director  120000            Sales
# 1       Jane     Smith         HR Coordinator   60000  Human Resources
# 2    Michael   Johnson      Software Engineer  110000               IT
# 3      Sarah  Williams   Marketing Specialist   75000            Sales
# 4      David     Brown             HR Manager   90000  Human Resources
# 5      Emily     Davis  IT Support Specialist   55000               IT
# 6      Jacob    Wilson   Sales Representative   80000            Sales
# 7     Olivia     Moore      Marketing Manager  100000            Sales
# 8      Ethan       Lee      Financial Analyst   85000            Sales
# 9     Sophia    Taylor           HR Assistant   50000  Human Resources
#
#   username
# 0   johdoe
# 1   jansmi
# 2   micjoh
# 3   sarwil
# 4   davbro
# 5   emidav
# 6   jacwil
# 7   olimoo
# 8   ethlee
# 9   soptay

# %%
employees.merge(users, on='username')
# Out:
#   first_name last_name              job_title  salary       department  \
# 0       John       Doe         Sales Director  120000            Sales
# 1       Jane     Smith         HR Coordinator   60000  Human Resources
# 2    Michael   Johnson      Software Engineer  110000               IT
# 3      Sarah  Williams   Marketing Specialist   75000            Sales
# 4      David     Brown             HR Manager   90000  Human Resources
# 5      Emily     Davis  IT Support Specialist   55000               IT
# 6      Jacob    Wilson   Sales Representative   80000            Sales
# 7     Olivia     Moore      Marketing Manager  100000            Sales
# 8      Ethan       Lee      Financial Analyst   85000            Sales
# 9     Sophia    Taylor           HR Assistant   50000  Human Resources
#
#   username                                           password  \
# 0   johdoe  7e684c07e48bf68c0181306c2dab1a0e2b8298e9a59a37...
# 1   jansmi  a6ab128c25d59951f9eb29a0b63806a0a2df924a384f61...
# 2   micjoh  9f01f5cfa05a6b14367d4d0e6c788c5977f094ad4e2381...
# 3   sarwil  fdb1e5c757d39e5f27065f12f27fbc94d50f47a66e8cdd...
# 4   davbro  1d99b7d777fb1b04ac1bea3d4b04a4ea5f654f9b304da4...
# 5   emidav  1953b5a2e8cc313b6db9f1708e9d0b84a84c6b3a60706e...
# 6   jacwil  8d5ee4f5e3a5e9202a2f21d3b7c30a10c9c51d0133a731...
# 7   olimoo  79cfd142536a5d27528d3306ef28e26d038c625764167b...
# 8   ethlee  5f51c17c9b81d68a1c9b99f1a8627a457bd0a4048d594c...
# 9   soptay  a429b013ebfb9f86a3cb8cf2311e2bfa3b00b238d439eb...
#
#                              email           phone         host
# 0         john.doe@mockcompany.com  (212) 591-7254  192.168.1.1
# 1       jane.smith@mockcompany.com  (312) 623-3364  192.168.1.2
# 2  michael.johnson@mockcompany.com  (415) 602-6872  192.168.1.3
# 3   sarah.williams@mockcompany.com  (212) 623-6568  192.168.1.1
# 4      david.brown@mockcompany.com  (312) 709-8933  192.168.1.2
# 5      emily.davis@mockcompany.com  (415) 775-6149  192.168.1.3
# 6     jacob.wilson@mockcompany.com  (212) 285-2027  192.168.1.1
# 7     olivia.moore@mockcompany.com  (212) 335-5297  192.168.1.1
# 8        ethan.lee@mockcompany.com  (212) 509-8922  192.168.1.1
# 9    sophia.taylor@mockcompany.com  (312) 826-6711  192.168.1.2

# %% [markdown]
# # Kolla vad Fredrik gör med Multiindexing
# - använder 'new_df' som vi skapade en bit upp i koden, som är sammaslagningen av employees och department.
# - Vi ska beräkna antalet anställda per department och deras medel lön.

# %%
new_df
# Out:
#   first_name last_name              job_title  salary       department  \
# 0       John       Doe         Sales Director  120000            Sales
# 1      Sarah  Williams   Marketing Specialist   75000            Sales
# 2      Jacob    Wilson   Sales Representative   80000            Sales
# 3     Olivia     Moore      Marketing Manager  100000            Sales
# 4      Ethan       Lee      Financial Analyst   85000            Sales
# 5       Jane     Smith         HR Coordinator   60000  Human Resources
# 6      David     Brown             HR Manager   90000  Human Resources
# 7     Sophia    Taylor           HR Assistant   50000  Human Resources
# 8    Michael   Johnson      Software Engineer  110000               IT
# 9      Emily     Davis  IT Support Specialist   55000               IT
#
#    department_head       location  office_number   budget
# 0   Sarah Williams       New York            101  1000000
# 1   Sarah Williams       New York            101  1000000
# 2   Sarah Williams       New York            101  1000000
# 3   Sarah Williams       New York            101  1000000
# 4   Sarah Williams       New York            101  1000000
# 5      David Brown        Chicago            202   800000
# 6      David Brown        Chicago            202   800000
# 7      David Brown        Chicago            202   800000
# 8  Michael Johnson  San Francisco            303  1200000
# 9  Michael Johnson  San Francisco            303  1200000

# %%
x = new_df.groupby(['department','department_head','location','office_number','budget'])
x['salary'].agg(['max','mean','count'])
# Out:
#                                                                         max  \
# department      department_head location      office_number budget
# Human Resources David Brown     Chicago       202           800000    90000
# IT              Michael Johnson San Francisco 303           1200000  110000
# Sales           Sarah Williams  New York      101           1000000  120000
#
#                                                                              mean  \
# department      department_head location      office_number budget
# Human Resources David Brown     Chicago       202           800000   66666.666667
# IT              Michael Johnson San Francisco 303           1200000  82500.000000
# Sales           Sarah Williams  New York      101           1000000  92000.000000
#
#                                                                      count
# department      department_head location      office_number budget
# Human Resources David Brown     Chicago       202           800000       3
# IT              Michael Johnson San Francisco 303           1200000      2
# Sales           Sarah Williams  New York      101           1000000      5

# %%
new_df.groupby(['department','department_head','location','office_number','budget'])['salary'].agg(['min','mean','max'])
# Out:
#                                                                        min  \
# department      department_head location      office_number budget
# Human Resources David Brown     Chicago       202           800000   50000
# IT              Michael Johnson San Francisco 303           1200000  55000
# Sales           Sarah Williams  New York      101           1000000  75000
#
#                                                                              mean  \
# department      department_head location      office_number budget
# Human Resources David Brown     Chicago       202           800000   66666.666667
# IT              Michael Johnson San Francisco 303           1200000  82500.000000
# Sales           Sarah Williams  New York      101           1000000  92000.000000
#
#                                                                         max
# department      department_head location      office_number budget
# Human Resources David Brown     Chicago       202           800000    90000
# IT              Michael Johnson San Francisco 303           1200000  110000
# Sales           Sarah Williams  New York      101           1000000  120000

# %% [markdown]
# # det bättre men svårare sättet:

# %%
new_df.groupby(['department','department_head','location','office_number','budget'], as_index=False).agg(
    number_of_emplyess = pd.NamedAgg(column='salary', aggfunc='count'),
    average_salary = pd.NamedAgg(column='salary', aggfunc='mean')
)
# Out:
#         department  department_head       location  office_number   budget  \
# 0  Human Resources      David Brown        Chicago            202   800000
# 1               IT  Michael Johnson  San Francisco            303  1200000
# 2            Sales   Sarah Williams       New York            101  1000000
#
#    number_of_emplyess  average_salary
# 0                   3    66666.666667
# 1                   2    82500.000000
# 2                   5    92000.000000
