# %% [markdown]
# ## Encoding categorical features
# [Recording](https://ithogskolan.sharepoint.com/:v:/s/AI23/EVhZ58xq_A5Dn1kxBId4xfwBG0BRRvaH00Yc0bVjtggtrQ?e=GxfWaJ)
# - Categorical features are non-numeric with a limited amount of possible options.
# - Before feeding them into most ML algorithms we must convert them into numerical features using either:
#     - **Label Encoding** Each unique category is assigned to a numerical value: 0, 1, 2, 3, ...
#     - **One-hot encoding** a new binary feature is created for each category. En del ML algoritmer tror att det är en inbördes ordning, tex 0, 1, 2,... och då kan man komma undan detta med denna metoden.

# %%
import pandas as pd
import seaborn as sns
import warnings

warnings.filterwarnings("ignore", "is_categorical_dtype")
warnings.filterwarnings("ignore", "use_inf_as_na")
warnings.filterwarnings("ignore", "The figure layout has changed to tight")
warnings.filterwarnings("ignore", "The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.")
warnings.filterwarnings("ignore", "is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.")
warnings.filterwarnings("ignore", "is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.  if is_sparse(pd_dtype):")
warnings.filterwarnings("ignore", "is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.  if is_sparse(pd_dtype) or not is_extension_array_dtype(pd_dtype):")
warnings.filterwarnings("ignore", "is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.")
warnings.filterwarnings(category=FutureWarning, action="ignore")

# %%
titanic = sns.load_dataset("titanic")
titanic.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True

# %%
titanic.info() # för att se vilka som är categorical
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 15 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   survived     891 non-null    int64
#  1   pclass       891 non-null    int64
#  2   sex          891 non-null    object
#  3   age          714 non-null    float64
#  4   sibsp        891 non-null    int64
#  5   parch        891 non-null    int64
#  6   fare         891 non-null    float64
#  7   embarked     889 non-null    object
#  8   class        891 non-null    category
#  9   who          891 non-null    object
#  10  adult_male   891 non-null    bool
#  11  deck         203 non-null    category
#  12  embark_town  889 non-null    object
#  13  alive        891 non-null    object
#  14  alone        891 non-null    bool
# dtypes: bool(2), category(2), float64(2), int64(4), object(5)
# memory usage: 80.7+ KB

# %% [markdown]
# Tar fram alla kolumner som är categorical, i en lista

# %%
#titanic.columns är en lista av alla kolumner
cat_columns = [col for col in titanic.columns if titanic[col].dtype in ['object','category']]
cat_columns
# Out:
# ['sex', 'embarked', 'class', 'who', 'deck', 'embark_town', 'alive']

# %%
df_categories = titanic[cat_columns]
df_categories.head()
# Out:
#       sex embarked  class    who deck  embark_town alive
# 0    male        S  Third    man  NaN  Southampton    no
# 1  female        C  First  woman    C    Cherbourg   yes
# 2  female        S  Third  woman  NaN  Southampton   yes
# 3  female        S  First  woman    C  Southampton   yes
# 4    male        S  Third    man  NaN  Southampton    no

# %%
for cat in cat_columns:
    print(f'{cat} : {df_categories[cat].unique()}')
    print("====================================================")
# Out:
# sex : ['male' 'female']
# ====================================================
# embarked : ['S' 'C' 'Q' nan]
# ====================================================
# class : ['Third', 'First', 'Second']
# Categories (3, object): ['First', 'Second', 'Third']
# ====================================================
# who : ['man' 'woman' 'child']
# ====================================================
# deck : [NaN, 'C', 'E', 'G', 'D', 'A', 'B', 'F']
# Categories (7, object): ['A', 'B', 'C', 'D', 'E', 'F', 'G']
# ====================================================
# embark_town : ['Southampton' 'Cherbourg' 'Queenstown' nan]
# ====================================================
# alive : ['no' 'yes']
# ====================================================

# %% [markdown]
# ### Label encoding
# - Label encoding maps each category into a numerical value.
# - Use label encoding if:
#     - Categories has a natural order
#     - If there are only two categories
#     - If using one-hot encoding leads to a large number of features

# %%
# Manual mapping
titanic["embarked"] = titanic["embarked"].map({"S":0,"C":1,"Q":2}) # map-funktionen tar en dict med översättningstabell

# %% [markdown]
# ### Auto mapping using Label Encoder from Scikit-learn

# %%
from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()

titanic["deck"] = le.fit_transform(titanic["deck"])
titanic.head()
# Out:
# ---------------------------------------------------------------------------
# FutureWarning                             Traceback (most recent call last)
# c:\Users\danie\Documents\GitHub\Databehandling_Daniel_Claesson\CodeAlong\L09_Encoding_ctaegorical_features.ipynb Cell 12 line 4
#       <a href='vscode-notebook-cell:/c%3A/Users/danie/Documents/GitHub/Databehandling_Daniel_Claesson/CodeAlong/L09_Encoding_ctaegorical_features.ipynb#X14sZmlsZQ%3D%3D?line=0'>1</a> from sklearn.preprocessing import LabelEncoder
#       <a href='vscode-notebook-cell:/c%3A/Users/danie/Documents/GitHub/Databehandling_Daniel_Claesson/CodeAlong/L09_Encoding_ctaegorical_features.ipynb#X14sZmlsZQ%3D%3D?line=1'>2</a> le = LabelEncoder()
# ----> <a href='vscode-notebook-cell:/c%3A/Users/danie/Documents/GitHub/Databehandling_Daniel_Claesson/CodeAlong/L09_Encoding_ctaegorical_features.ipynb#X14sZmlsZQ%3D%3D?line=3'>4</a> titanic["deck"] = le.fit_transform(titanic["deck"])
#       <a href='vscode-notebook-cell:/c%3A/Users/danie/Documents/GitHub/Databehandling_Daniel_Claesson/CodeAlong/L09_Encoding_ctaegorical_features.ipynb#X14sZmlsZQ%3D%3D?line=4'>5</a> titanic.head()
#
# File c:\Users\danie\Anaconda3\envs\databeh\Lib\site-packages\sklearn\utils\_set_output.py:140, in _wrap_method_output.<locals>.wrapped(self, X, *args, **kwargs)
#     138 @wraps(f)
#     139 def wrapped(self, X, *args, **kwargs):
# --> 140     data_to_wrap = f(self, X, *args, **kwargs)
#     141     if isinstance(data_to_wrap, tuple):
#     142         # only wrap the first output for cross decomposition
#     143         return (
#     144             _wrap_data_with_container(method, data_to_wrap[0], X, self),
#     145             *data_to_wrap[1:],
#     146         )
#
# File c:\Users\danie\Anaconda3\envs\databeh\Lib\site-packages\sklearn\preprocessing\_label.py:116, in LabelEncoder.fit_transform(self, y)
#     103 def fit_transform(self, y):
#     104     """Fit label encoder and return encoded labels.
#     105
#     106     Parameters
#    (...)
#     114         Encoded labels.
#     115     """
# --> 116     y = column_or_1d(y, warn=True)
#     117     self.classes_, y = _unique(y, return_inverse=True)
#     118     return y
#
# File c:\Users\danie\Anaconda3\envs\databeh\Lib\site-packages\sklearn\utils\validation.py:1179, in column_or_1d(y, dtype, warn)
#    1153 """Ravel column or 1d numpy array, else raises an error.
#    1154
#    1155 Parameters
#    (...)
#    1176     If `y` is not a 1D array or a 2D array with a single row or column.
#    1177 """
#    1178 xp, _ = get_namespace(y)
# -> 1179 y = check_array(
#    1180     y,
#    1181     ensure_2d=False,
#    1182     dtype=dtype,
#    1183     input_name="y",
#    1184     force_all_finite=False,
#    1185     ensure_min_samples=0,
#    1186 )
#    1188 shape = y.shape
#    1189 if len(shape) == 1:
#
# File c:\Users\danie\Anaconda3\envs\databeh\Lib\site-packages\sklearn\utils\validation.py:782, in check_array(array, accept_sparse, accept_large_sparse, dtype, order, copy, force_all_finite, ensure_2d, allow_nd, ensure_min_samples, ensure_min_features, estimator, input_name)
#     778         dtype_orig = np.result_type(*dtypes_orig)
#     780 elif hasattr(array, "iloc") and hasattr(array, "dtype"):
#     781     # array is a pandas series
# --> 782     pandas_requires_conversion = _pandas_dtype_needs_early_conversion(array.dtype)
#     783     if isinstance(array.dtype, np.dtype):
#     784         dtype_orig = array.dtype
#
# File c:\Users\danie\Anaconda3\envs\databeh\Lib\site-packages\sklearn\utils\validation.py:605, in _pandas_dtype_needs_early_conversion(pd_dtype)
#     600 if is_bool_dtype(pd_dtype):
#     601     # bool and extension booleans need early converstion because __array__
#     602     # converts mixed dtype dataframes into object dtypes
#     603     return True
# --> 605 if is_sparse(pd_dtype):
#     606     # Sparse arrays will be converted later in `check_array`
#     607     return False
#     609 try:
#
# File c:\Users\danie\Anaconda3\envs\databeh\Lib\site-packages\pandas\core\dtypes\common.py:211, in is_sparse(arr)
#     168 def is_sparse(arr) -> bool:
#     169     """
#     170     Check whether an array-like is a 1-D pandas sparse array.
#     171
#    (...)
#     209     Returns `False` if the parameter has more than one dimension.
#     210     """
# --> 211     warnings.warn(
#     212         "is_sparse is deprecated and will be removed in a future "
#     213         "version. Check `isinstance(dtype, pd.SparseDtype)` instead.",
#     214         FutureWarning,
#     215         stacklevel=find_stack_level(),
#     216     )
#     218     dtype = getattr(arr, "dtype", arr)
#     219     return isinstance(dtype, SparseDtype)
#
# FutureWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.

# %% [markdown]
# ### One-hot encoding
# - In one-hot encoding, a new binary feature is created for each category, and the value of that feature is set to 1 if the observation belongs to that category, and 0 otherwise.
# - Use one-hot encoding if:
#     - Categories have no natural order
#     - Number of categories is small (but not 2)
# - Use function **get_dummies()**

# %%
titanic.head()
# Out:
#    survived  pclass  sex   age  sibsp  parch     fare  embarked  class  who  \
# 0         0       3    1  22.0      1      0   7.2500       0.0      2    1
# 1         1       1    0  38.0      1      0  71.2833       1.0      0    2
# 2         1       3    0  26.0      0      0   7.9250       0.0      2    2
# 3         1       1    0  35.0      1      0  53.1000       0.0      0    2
# 4         0       3    1  35.0      0      0   8.0500       0.0      2    1
#
#    adult_male  deck  embark_town  alive  alone
# 0           1     7            2      0      0
# 1           0     2            0      1      0
# 2           0     7            2      1      1
# 3           0     2            2      1      0
# 4           1     7            2      0      1

# %%
titanic.to_json("../Data/titanic_encoded.json", orient="records") # Sparar denna datan som en .json som används i L10.

# %%
pd.get_dummies(data=titanic, columns=['who'])
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare  embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500       0.0   Third
# 1           1       1  female  38.0      1      0  71.2833       1.0   First
# 2           1       3  female  26.0      0      0   7.9250       0.0   Third
# 3           1       1  female  35.0      1      0  53.1000       0.0   First
# 4           0       3    male  35.0      0      0   8.0500       0.0   Third
# ..        ...     ...     ...   ...    ...    ...      ...       ...     ...
# 886         0       2    male  27.0      0      0  13.0000       0.0  Second
# 887         1       1  female  19.0      0      0  30.0000       0.0   First
# 888         0       3  female   NaN      1      2  23.4500       0.0   Third
# 889         1       1    male  26.0      0      0  30.0000       1.0   First
# 890         0       3    male  32.0      0      0   7.7500       2.0   Third
#
#      adult_male  deck  embark_town alive  alone  who_child  who_man  who_woman
# 0          True     7  Southampton    no  False      False     True      False
# 1         False     2    Cherbourg   yes  False      False    False       True
# 2         False     7  Southampton   yes   True      False    False       True
# 3         False     2  Southampton   yes  False      False    False       True
# 4          True     7  Southampton    no   True      False     True      False
# ..          ...   ...          ...   ...    ...        ...      ...        ...
# 886        True     7  Southampton    no   True      False     True      False
# 887       False     1  Southampton   yes   True      False    False       True
# 888       False     7  Southampton    no  False      False    False       True
# 889        True     2    Cherbourg   yes   True      False     True      False
# 890        True     7   Queenstown    no   True      False     True      False
#
# [891 rows x 17 columns]

# %% [markdown]
# ### Auto-map remaining non-numerical features

# %%
cat_columns = [col for col in titanic.columns if titanic[col].dtype in ['object','category','bool']]
cat_columns
# Out:
# ['sex', 'class', 'who', 'adult_male', 'deck', 'embark_town', 'alive', 'alone']

# %%
for column in cat_columns:
    titanic[column] = le.fit_transform(titanic[column])

titanic
# Out:
#      survived  pclass  sex   age  sibsp  parch     fare  embarked  class  who  \
# 0           0       3    1  22.0      1      0   7.2500       0.0      2    1
# 1           1       1    0  38.0      1      0  71.2833       1.0      0    2
# 2           1       3    0  26.0      0      0   7.9250       0.0      2    2
# 3           1       1    0  35.0      1      0  53.1000       0.0      0    2
# 4           0       3    1  35.0      0      0   8.0500       0.0      2    1
# ..        ...     ...  ...   ...    ...    ...      ...       ...    ...  ...
# 886         0       2    1  27.0      0      0  13.0000       0.0      1    1
# 887         1       1    0  19.0      0      0  30.0000       0.0      0    2
# 888         0       3    0   NaN      1      2  23.4500       0.0      2    2
# 889         1       1    1  26.0      0      0  30.0000       1.0      0    1
# 890         0       3    1  32.0      0      0   7.7500       2.0      2    1
#
#      adult_male  deck  embark_town  alive  alone
# 0             1     7            2      0      0
# 1             0     2            0      1      0
# 2             0     7            2      1      1
# 3             0     2            2      1      0
# 4             1     7            2      0      1
# ..          ...   ...          ...    ...    ...
# 886           1     7            2      0      1
# 887           0     1            2      1      1
# 888           0     7            2      0      0
# 889           1     2            0      1      1
# 890           1     7            1      0      1
#
# [891 rows x 15 columns]
